# %%
#!/usr/bin/env python3
"""
Script simple de classification de fichiers médicaux
Fait exactement la même chose que LangGraph mais en 90% moins de code !
"""

import os
import shutil
import json
from datetime import datetime
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# Configuration
BASE_DIR = os.path.abspath(r"C:\Users\kosmo\pycode\Iqvia_process")
CHEMIN_SOURCE = os.path.join(BASE_DIR, "ProcessEx")
CHEMIN_DEPOTS = os.path.join(BASE_DIR, "Depots")

# Initialiser le LLM
api_key = os.getenv('OPENAI_API_KEY')
if not api_key:
    print("⚠️ ATTENTION: Clé API non trouvée dans les variables d'environnement")
    api_key = "votre_clé_api_openai_ici"  # À remplacer par votre vraie clé

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0,
    api_key=api_key
)

def detection_mots_cles_medicaux(titre: str) -> dict:
    """Détection fallback par mots-clés"""
    titre_lower = titre.lower()
    
    termes_medicaux = {
        'cancer': 'oncologie', 'tumeur': 'oncologie', 'oncologie': 'oncologie',
        'prostate': 'oncologie', 'sein': 'oncologie', 'poumon': 'oncologie',
        'diabète': 'diabetologie', 'diabete': 'diabetologie', 'glycémie': 'diabetologie',
        'cardiaque': 'cardiologie', 'coeur': 'cardiologie', 'cœur': 'cardiologie',
        'hypertension': 'cardiologie', 'infarctus': 'cardiologie',
        'alzheimer': 'neurologie', 'parkinson': 'neurologie', 'neurologie': 'neurologie',
        'asthme': 'pneumologie', 'pneumonie': 'pneumologie', 'bronchite': 'pneumologie',
        'eczéma': 'dermatologie', 'eczema': 'dermatologie', 'psoriasis': 'dermatologie'
    }
    
    maladies_detectees = [terme for terme in termes_medicaux.keys() if terme in titre_lower]
    
    if maladies_detectees:
        categorie_finale = termes_medicaux[maladies_detectees[0]]
        confiance = "haute" if len(maladies_detectees) > 1 else "moyenne"
        return {
            "contient_maladie": True,
            "maladies_detectees": maladies_detectees,
            "categorie_medicale": categorie_finale,
            "confiance": confiance,
            "titre_normalise": titre
        }
    
    return {
        "contient_maladie": False,
        "maladies_detectees": [],
        "categorie_medicale": "aucune",
        "confiance": "faible",
        "titre_normalise": titre
    }

def analyser_titre_avec_llm(titre: str) -> dict:
    """Analyse avec LLM - même prompt que LangGraph"""
    try:
        analysis_prompt_template = ChatPromptTemplate.from_messages([
            ("system", "Vous êtes un expert en terminologie médicale. Analysez les titres de documents médicaux avec précision."),
            ("human", """
Analysez ce titre de fichier médical: "{titre}"

RÈGLES PRIORITAIRES D'EXCLUSION:
1. Si le titre contient "ABBVIE" → catégorie: aucune (dossier AUTRES)
2. Si le titre contient des termes commerciaux/entreprise → catégorie: aucune (dossier AUTRES)

APRÈS vérification des exclusions, recherchez ces termes médicaux: 
cancer, diabète, cardiaque, cœur, hypertension, Alzheimer, asthme, prostate, sein, poumon, neurologie, psychiatrie, dermatologie, oncologie, pneumologie, DLBCL, lymphome.

EXEMPLES D'ANALYSE:
- "3252322 - Suivi Xponent std cancer de la prostate 2025" → contient: cancer, prostate → oncologie
- "Rapport diabète type 2 France" → contient: diabète → diabetologie  
- "Formation commerciale 2025" → aucun terme médical → aucune
- "IQVIA pour ABBVIE_Channel Dynamics_Bilan Marché DLBCL_2025" → contient ABBVIE (exclusion) → aucune

Répondez UNIQUEMENT en JSON valide:
{{
    "contient_maladie": true/false,
    "maladies_detectees": ["terme1", "terme2"],
    "categorie_medicale": "oncologie/cardiologie/neurologie/diabetologie/pneumologie/dermatologie/autre/aucune",
    "confiance": "haute/moyenne/faible",
    "titre_normalise": "{titre}"
}}
            """)
        ])
        
        prompt_value = analysis_prompt_template.invoke({"titre": titre})
        response = llm.invoke(prompt_value.to_messages())
        content = response.content.strip()
        
        # Nettoyer le JSON
        if "```json" in content:
            content = content.split("```json")[1].split("```")[0]
        elif "```" in content:
            content = content.split("```")[1].split("```")[0]
        
        return json.loads(content.strip())
        
    except Exception as e:
        print(f"❌ Erreur LLM pour '{titre[:30]}...': {e}")
        return detection_mots_cles_medicaux(titre)

def rechercher_fichiers():
    """Phase 1: Recherche tous les fichiers dans ProcessEx"""
    print("🔍 PHASE 1: Recherche des fichiers...")
    print("-" * 50)
    
    if not os.path.exists(CHEMIN_SOURCE):
        print(f"❌ Erreur: {CHEMIN_SOURCE} n'existe pas")
        return []
    
    fichiers_trouves = []
    dossiers_stats = {}
    
    for item in os.listdir(CHEMIN_SOURCE):
        item_path = os.path.join(CHEMIN_SOURCE, item)
        if os.path.isdir(item_path):
            print(f"📂 Analyse du dossier: {item}")
            count = 0
            
            for root, dirs, files in os.walk(item_path):
                for file in files:
                    if file.lower().endswith(('.ppt', '.pptx', '.pdf')):
                        fichiers_trouves.append(os.path.join(root, file))
                        count += 1
            
            dossiers_stats[item] = count
            print(f"  ✅ {count} fichier(s) trouvé(s)")
    
    print(f"\n📊 TOTAL: {len(fichiers_trouves)} fichiers dans {len(dossiers_stats)} dossiers")
    for dossier, count in dossiers_stats.items():
        print(f"  • {dossier}: {count}")
    
    return fichiers_trouves

def copier_fichiers(fichiers_trouves):
    """Phase 2: Copie vers Depots"""
    print(f"\n📋 PHASE 2: Copie vers {CHEMIN_DEPOTS}...")
    print("-" * 50)
    
    # Créer le dossier Depots
    os.makedirs(CHEMIN_DEPOTS, exist_ok=True)
    print(f"✅ Dossier Depots prêt")
    
    copied = 0
    for file_path in fichiers_trouves:
        file_name = os.path.basename(file_path)
        destination = os.path.join(CHEMIN_DEPOTS, file_name)
        
        try:
            shutil.copy(file_path, destination)
            copied += 1
        except Exception as e:
            print(f"❌ Erreur copie {file_name}: {e}")
    
    print(f"✅ {copied}/{len(fichiers_trouves)} fichiers copiés")
    return copied

def analyser_et_classer():
    """Phase 3: Analyse LLM et classification"""
    print(f"\n🤖 PHASE 3: Analyse IA et classification...")
    print("-" * 50)
    
    # Mode LLM ou fallback
    use_llm = api_key != "votre_clé_api_openai_ici"
    print(f"Mode: {'🔥 LLM' if use_llm else '🔧 Mots-clés'}")
    
    fichiers_a_analyser = [f for f in os.listdir(CHEMIN_DEPOTS) 
                          if f.lower().endswith(('.ppt', '.pptx', '.pdf'))]
    
    analyses = []
    medicaux = 0
    
    for i, file_name in enumerate(fichiers_a_analyser, 1):
        titre = os.path.splitext(file_name)[0]
        print(f"[{i:2d}/{len(fichiers_a_analyser)}] {file_name[:60]}...")
        
        # Analyser
        if use_llm:
            resultat = analyser_titre_avec_llm(titre)
        else:
            resultat = detection_mots_cles_medicaux(titre)
        
        analyses.append({
            'fichier': file_name,
            'maladies_detectees': resultat['maladies_detectees'],
            'categorie_medicale': resultat['categorie_medicale'],
            'confiance': resultat['confiance'],
            'contient_maladie': resultat['contient_maladie']
        })
        
        # Classer le fichier
        ancien_chemin = os.path.join(CHEMIN_DEPOTS, file_name)
        
        if resultat["contient_maladie"]:
            # Dossier médical
            categorie = resultat["categorie_medicale"]
            dossier_medical = os.path.join(CHEMIN_DEPOTS, f"MEDICAL_{categorie.upper()}")
            os.makedirs(dossier_medical, exist_ok=True)
            nouveau_chemin = os.path.join(dossier_medical, file_name)
            medicaux += 1
            print(f"     → MEDICAL_{categorie.upper()}/ ({'|'.join(resultat['maladies_detectees'])})")
        else:
            # Dossier autres
            dossier_autres = os.path.join(CHEMIN_DEPOTS, "AUTRES")
            os.makedirs(dossier_autres, exist_ok=True)
            nouveau_chemin = os.path.join(dossier_autres, file_name)
            print(f"     → AUTRES/")
        
        # Déplacer
        try:
            shutil.move(ancien_chemin, nouveau_chemin)
        except Exception as e:
            print(f"     ❌ Erreur déplacement: {e}")
    
    print(f"\n📊 RÉSULTATS: {medicaux}/{len(analyses)} fichiers médicaux classés")
    return analyses

def generer_rapport(analyses):
    """Phase 4: Génération du rapport"""
    print(f"\n📝 PHASE 4: Génération du rapport...")
    print("-" * 50)
    
    fichiers_medicaux = sum(1 for a in analyses if a['contient_maladie'])
    categories = {}
    for a in analyses:
        if a['contient_maladie']:
            cat = a['categorie_medicale']
            categories[cat] = categories.get(cat, 0) + 1
    
    rapport = f"""# 📊 Rapport d'Analyse de Fichiers Médicaux (Script Simple)

**Date d'analyse :** {datetime.now().strftime("%d/%m/%Y à %H:%M:%S")}  
**Dossier analysé :** `{CHEMIN_DEPOTS}`
**Méthode :** Script Python direct (sans LangGraph)

---

## 📈 Résumé Statistique

| Métrique | Valeur |
|----------|--------|
| **Fichiers analysés** | {len(analyses)} |
| **Fichiers médicaux** | {fichiers_medicaux} |
| **Fichiers non-médicaux** | {len(analyses) - fichiers_medicaux} |
| **Catégories détectées** | {len(categories)} |

---

## 🏥 Répartition par Spécialités

"""
    
    if categories:
        for cat, count in sorted(categories.items()):
            pct = (count / fichiers_medicaux * 100) if fichiers_medicaux > 0 else 0
            rapport += f"- **{cat.title()}** : {count} fichier(s) ({pct:.1f}%)\n"
    else:
        rapport += "Aucune catégorie médicale détectée.\n"
    
    rapport += "\n---\n\n## 📋 Détail par Fichier\n\n"
    
    for analyse in analyses:
        dossier = f"MEDICAL_{analyse['categorie_medicale'].upper()}" if analyse['contient_maladie'] else "AUTRES"
        rapport += f"""### 📄 {analyse['fichier']}
- **Maladies :** {', '.join(analyse['maladies_detectees']) if analyse['maladies_detectees'] else 'Aucune'}
- **Catégorie :** {analyse['categorie_medicale']}
- **Dossier :** `{dossier}/`

"""
    
    rapport += f"""---

## ⚙️ Technologie

- **Script :** Python simple (90% moins de code que LangGraph)
- **LLM :** ChatOpenAI GPT-4o-mini 
- **Fallback :** Détection par mots-clés
- **Performance :** {len(analyses)} fichiers traités

---

*Rapport généré par script Python simple - Preuve que LangGraph était de la sur-ingénierie ! 😉*
"""
    
    # Sauvegarder
    chemin_rapport = os.path.join(CHEMIN_DEPOTS, "RAPPORT_SIMPLE.md")
    with open(chemin_rapport, 'w', encoding='utf-8') as f:
        f.write(rapport)
    
    print(f"✅ Rapport sauvé: {chemin_rapport}")

def main():
    """Fonction principale - workflow simple"""
    print("🚀 CLASSIFICATEUR MÉDICAL SIMPLE")
    print("=" * 60)
    print(f"Source: {CHEMIN_SOURCE}")
    print(f"Destination: {CHEMIN_DEPOTS}")
    print("=" * 60)
    
    # Workflow en 4 étapes simples
    fichiers = rechercher_fichiers()
    if not fichiers:
        print("❌ Aucun fichier trouvé - Arrêt")
        return
    
    copier_fichiers(fichiers)
    analyses = analyser_et_classer()
    generer_rapport(analyses)
    
    print("\n" + "🎉" * 20)
    print("✅ TERMINÉ - Même résultat qu'avec LangGraph !")
    print("💡 90% moins de code, même performance")
    print("🎉" * 20)

if __name__ == "__main__":
    main()
# Out:
# 🚀 CLASSIFICATEUR MÉDICAL SIMPLE
# ============================================================
# Source: C:\Users\kosmo\pycode\Iqvia_process\ProcessEx
# Destination: C:\Users\kosmo\pycode\Iqvia_process\Depots
# ============================================================
# 🔍 PHASE 1: Recherche des fichiers...
# --------------------------------------------------
# 📂 Analyse du dossier: AAA
#   ✅ 11 fichier(s) trouvé(s)
# 📂 Analyse du dossier: ABBOTT DC
#   ✅ 56 fichier(s) trouvé(s)
# 📂 Analyse du dossier: ABBOTT DIAG
#   ✅ 10 fichier(s) trouvé(s)
# 📂 Analyse du dossier: ABBOTT France
#   ✅ 4 fichier(s) trouvé(s)
# 📂 Analyse du dossier: ABBVIE
#   ✅ 142 fichier(s) trouvé(s)
# 📂 Analyse du dossier: ABOCA
#   ✅ 5 fichier(s) trouvé(s)
# 📂 Analyse du dossier: ACCORD HEALTHCARE
#   ✅ 3 fichier(s) trouvé(s)
# 📂 Analyse du dossier: AIR LIQUIDE
#   ✅ 0 fichier(s) trouvé(s)
# 📂 Analyse du dossier: ALCON
#   ✅ 7 fichier(s) trouvé(s)
#
# 📊 TOTAL: 238 fichiers dans 9 dossiers
#   • AAA: 11
#   • ABBOTT DC: 56
#   • ABBOTT DIAG: 10
#   • ABBOTT France: 4
#   • ABBVIE: 142
#   • ABOCA: 5
#   • ACCORD HEALTHCARE: 3
#   • AIR LIQUIDE: 0
#   • ALCON: 7
#
# 📋 PHASE 2: Copie vers C:\Users\kosmo\pycode\Iqvia_process\Depots...
# --------------------------------------------------
# ✅ Dossier Depots prêt
# ✅ 238/238 fichiers copiés
#
# 🤖 PHASE 3: Analyse IA et classification...
# --------------------------------------------------
# Mode: 🔥 LLM
# [ 1/224] #3240236  -  IQVIA pour ALCON - Oneshot 2025 V2 Signé.pdf...
#      → AUTRES/
# [ 2/224] #3240236  -  IQVIA pour ALCON - Oneshot 2025 V2.pdf...
#      → AUTRES/
# [ 3/224] 0 - AbbVie Master ILSA Global 0116-0119.pdf...
#      → AUTRES/
# [ 4/224] 065309  - IQVIA.pdf...
#      → AUTRES/
# [ 5/224] 067182 - IQVIA.pdf...
#      → AUTRES/
# [ 6/224] 1 - AbbVie-MSA16-19-Addendum17-19FINAL.PDF...
#      → AUTRES/
# [ 7/224] 10 - IQVIA ILSA SCC - AMENDMENT NO 10 26Oct2022 - signed.pdf...
#      → AUTRES/
# [ 8/224] 11 - AbbVie_ILSA AMENDMENT 11 for 90days Apr2023  FE.pdf...
#      → AUTRES/
# [ 9/224] 12- S-AbbVie_ILSA_MSA_Amendment_No._12.pdf...
#      → AUTRES/
# [10/224] 2 - s-AbbVie IMS Global Master InfoLicandSvcs Agreement_Amen...
#      → AUTRES/
# [11/224] 2024_Order81007080.pdf...
#      → AUTRES/
# [12/224] 2025 Abbvie - SOW 3260834 ICC MDM v4 (003) (1) - s.pdf...
#      → AUTRES/
# [13/224] 2025 Abbvie - SOW 3263295 OEC MDM v3 - signed.pdf...
#      → AUTRES/
# [14/224] 2025-BURINBX-45513-POCN-IQVIA-Signed.pdf...
#      → AUTRES/
# [15/224] 2025_Order81009181 - Xponent STD 2025.pdf...
#      → AUTRES/
# [16/224] 2757739 ABBVIE FA 4038099752.pdf...
#      → AUTRES/
# [17/224] 2757739 ABBVIE FA 4038099753.pdf...
#      → AUTRES/
# [18/224] 2757739 ABBVIE FA 4038102924.pdf...
#      → AUTRES/
# [19/224] 2757739 ABBVIE FA 4038102925.pdf...
#      → AUTRES/
# [20/224] 2757739 ABBVIE FA 4038105301.pdf...
#      → AUTRES/
# [21/224] 2757739 ABBVIE FA 4038105302.pdf...
#      → AUTRES/
# [22/224] 2757739 ABBVIE FA 4038107747.pdf...
#      → AUTRES/
# [23/224] 2757739 ABBVIE FA 4038107748.pdf...
#      → AUTRES/
# [24/224] 2757739 ABBVIE FA 4038110294.pdf...
#      → AUTRES/
# [25/224] 2757739 ABBVIE FA 4038110295.pdf...
#      → AUTRES/
# [26/224] 2757739 ABBVIE FA 4038113338.pdf...
#      → AUTRES/
# [27/224] 2757739 ABBVIE FA 4038113339.pdf...
#      → AUTRES/
# [28/224] 2757739 ABBVIE FA 4038116002.pdf...
#      → AUTRES/
# [29/224] 2757739 ABBVIE FA 4038116003.pdf...
#      → AUTRES/
# [30/224] 2757739 ABBVIE FA 4038118216.pdf...
#      → AUTRES/
# [31/224] 2757739 ABBVIE FA 4038118217.pdf...
#      → AUTRES/
# [32/224] 2757739 ABBVIE FA 4038120327.pdf...
#      → AUTRES/
# [33/224] 2757739 ABBVIE FA 4038120328.pdf...
#      → AUTRES/
# [34/224] 2757739 ABBVIE FA 4038122789.pdf...
#      → AUTRES/
# [35/224] 2757739 ABBVIE FA 4038122790.pdf...
#      → AUTRES/
# [36/224] 2757739 ABBVIE FA 4038125360.pdf...
#      → AUTRES/
# [37/224] 2757739 ABBVIE FA 4038125361.pdf...
#      → AUTRES/
# [38/224] 2757739_UPDATE_Change Order Form 1_20240311_V1.0_signed.pdf...
#      → AUTRES/
# [39/224] 2757739_UPDATE_PO4201992624.PDF...
#      → AUTRES/
# [40/224] 2969820_ALCON RNW ONKEY 2025.pdf...
#      → AUTRES/
# [41/224] 3047384_IQVIA pour ABBOTT DC_Suivi COHORTES pharmacies 2023-...
#      → AUTRES/
# [42/224] 3051959 MASTER OFFICINE RNW 2024.pdf...
#      → AUTRES/
# [43/224] 3054811 ABBOTT DC RNW ONKEY 2025.pdf...
#      → AUTRES/
# [44/224] 3070545 ABBVIE INV 4038116990.pdf...
#      → AUTRES/
# [45/224] 3070545 ABBVIE INV 4038118229.pdf...
#      → AUTRES/
# [46/224] 3070545 ABBVIE INV 4038118230.pdf...
#      → AUTRES/
# [47/224] 3070545 ABBVIE INV 4038120384.pdf...
#      → AUTRES/
# [48/224] 3070545 ABBVIE INV 4038120385.pdf...
#      → AUTRES/
# [49/224] 3070545 ABBVIE INV 4038122814.pdf...
#      → AUTRES/
# [50/224] 3070545 ABBVIE INV 4038122815.pdf...
#      → AUTRES/
# [51/224] 3070545 ABBVIE INV 4038125358.pdf...
#      → AUTRES/
# [52/224] 3070545 ABBVIE INV 4038125359.pdf...
#      → AUTRES/
# [53/224] 3070545 ABBVIE INV 4038125360.pdf...
#      → AUTRES/
# [54/224] 3070545 ABBVIE INV 4038127546.pdf...
#      → AUTRES/
# [55/224] 3070545 ABBVIE INV 4038127547.pdf...
#      → AUTRES/
# [56/224] 3070545 _ENVOL_Change Order Form #1_20241104_signed.pdf...
#      → AUTRES/
# [57/224] 3073808_-_IQVIA_ABBVIE_SOW_-_De-ID_-_Implementatio.pdf...
#      → AUTRES/
# [58/224] 3098949 ABBVIE SOW OneKey 2025 - 2028_EUR signed I.pdf...
#      → AUTRES/
# [59/224] 3098949 ABBVIE SOW OneKey 2025 - 2028_with not exceed amount...
#      → AUTRES/
# [60/224] 3181844 _IQVIA pour ABBOTT DC_Suivi national du FSL2 par seg...
#      → MEDICAL_DIABETOLOGIE/ (diabète)
# [61/224] 3181844 _IQVIA pour ABBOTT DC_Suivi national du FSL2 par seg...
#      → MEDICAL_DIABETOLOGIE/ (diabète)
# [62/224] 3181844 _IQVIA pour ABBOTT DC_Suivi national du FSL2 par seg...
#      → MEDICAL_DIABETOLOGIE/ (diabète)
# [63/224] 3181845_IQVIA pour Abbott DC_Suivi FSL Dataset au secteur 20...
#      → AUTRES/
# [64/224] 3181845_IQVIA pour Abbott DC_Suivi FSL Dataset au secteur 20...
#      → AUTRES/
# [65/224] 3181845_IQVIA pour Abbott DC_Suivi FSL Dataset au secteur 20...
#      → AUTRES/
# [66/224] 3181845_IQVIA pour Abbott DC_Suivi FSL Dataset au secteur 20...
#      → AUTRES/
# [67/224] 3192153 MASTER OFFICINE RNW 2025 - signé MK.pdf...
#      → AUTRES/
# [68/224] 3195429_ABBOTT Rapid_SOW_IQVIA_signé.pdf...
#      → AUTRES/
# [69/224] 3201575_IQVIA pour AbbVie_RNW Veille promotionnelle 2025.pdf...
#      → AUTRES/
# [70/224] 3201575_IQVIA pour AbbVie_RNW Veille promotionnelle 2025.ppt...
#      → AUTRES/
# [71/224] 3204720 IQVIA pour ABBOTT DC - Suivi DOM 2025 V2 correction ...
#      → AUTRES/
# [72/224] 3204720 IQVIA pour ABBOTT DC - Suivi DOM 2025 V2.pdf...
#      → AUTRES/
# [73/224] 3205413 MATCH Targeting Tool running 2025.pdf...
#      → AUTRES/
# [74/224] 3208984_ALCON OKLA RNW ONKEY 2025.pdf...
#      → AUTRES/
# [75/224] 3214024 Sow_IQVIA_3035162 Xponent Specialistes 2025 - signé ...
#      → AUTRES/
# [76/224] 3214024 Sow_IQVIA_3035162 Xponent Specialistes 2025 - signé....
#      → AUTRES/
# [77/224] 3225553 - Proposition commerciale pour ABBVIE - LTD Immunolo...
#      → AUTRES/
# [78/224] 3225553 - Proposition commerciale pour ABBVIE - LTD Immunolo...
#      → AUTRES/
# [79/224] 3229569 - AAA Data - Reportive - Formation Q1 2025 - V1.2 (0...
#      → AUTRES/
# [80/224] 3229569 - AAA Data - Reportive - Formation Q1 2025 - V1.2.pd...
#      → AUTRES/
# [81/224] 3229569 - AAA Data - Reportive - Formation Q1 2025 - V1.2sig...
#      → AUTRES/
# [82/224] 3234632_IQVIA pour Abbott DC_Suivi FSL Dataset - Ajout secto...
#      → AUTRES/
# [83/224] 3234632_IQVIA pour Abbott DC_Suivi FSL Dataset - Ajout secto...
#      → AUTRES/
# [84/224] 3234632_IQVIA pour Abbott DC_Suivi FSL LTD  Dataset - Ajouts...
#      → AUTRES/
# [85/224] 3234632_IQVIA pour Abbott DC_Suivi FSL LTD & Dataset - Ajout...
#      → AUTRES/
# [86/224] 3234632_IQVIA pour Abbott DC_Suivi FSL LTD & Dataset - Ajout...
#      → AUTRES/
# [87/224] 3235210_Iqvia pour AA_ Suivi national du marché Vistabel.pdf...
#      → AUTRES/
# [88/224] 3235882_IQVIA pour ABOCA - Ajustement de sectoriation 2025 V...
#      → AUTRES/
# [89/224] 3235882_IQVIA pour ABOCA - Ajustement de sectoriation 2025.p...
#      → AUTRES/
# [90/224] 3236804_IQVIA pour ABBOTT DC_Suivi COHORTES pharmacies 2025 ...
#      → AUTRES/
# [91/224] 3236804_IQVIA pour ABBOTT DC_Suivi COHORTES pharmacies 2025 ...
#      → AUTRES/
# [92/224] 3236804_IQVIA pour ABBOTT DC_Suivi COHORTES pharmacies 2025 ...
#      → AUTRES/
# [93/224] 3244204_ABBOTT France_Migration Connecteur vers SFDC BU CRM....
#      → AUTRES/
# [94/224] 3244204_ABBOTT France_Migration Connecteur vers SFDC BU CRM_...
#      → AUTRES/
# [95/224] 3248497_IQVIA for AbbVie - SOW formation Marketing.pdf...
#      → AUTRES/
# [96/224] 3252322 - Suivi Xponent std cancer de la prostate 2025 - sig...
#      → MEDICAL_ONCOLOGIE/ (cancer|prostate)
# [97/224] 3252322 - Suivi Xponent std cancer de la prostate 2025.pdf...
#      → MEDICAL_ONCOLOGIE/ (cancer|prostate)
# [98/224] 3253042 - IQVIA pour ABBVIE - Xponent hebdo Immuno Prolongat...
#      → AUTRES/
# [99/224] 3255485_IQVIAForAbbottRDID_StrategicMarketExpansion_Italy (1...
#      → AUTRES/
# [100/224] 3255485_IQVIAForAbbottRDID_StrategicMarketExpansion_Italy V2...
#      → AUTRES/
# [101/224] 3255485_IQVIAForAbbottRDID_StrategicMarketExpansion_Italy_14...
#      → AUTRES/
# [102/224] 3269167_IQVIA pour ABBVIE_Channel Dynamics_Bilan Marché LLC_...
#      → AUTRES/
# [103/224] 3269167_IQVIA pour ABBVIE_Channel Dynamics_Bilan Marché LLC_...
#      → AUTRES/
# [104/224] 3270123 - SOW AAA 2025 Licence Onekey Live Access additionne...
#      → AUTRES/
# [105/224] 3270123 - SOW AAA 2025 Licence Onekey Live Access additionne...
#      → AUTRES/
# [106/224] 3270205_IQVIA pour ABBVIE_Channel Dynamics_Bilan Marché DLBC...
#      → AUTRES/
# [107/224] 3270205_IQVIA pour ABBVIE_Channel Dynamics_Bilan Marché DLBC...
#      → MEDICAL_ONCOLOGIE/ (DLBCL)
# [108/224] 4 - AbbVie IQVIA Global Master InfoLicandSvcs Agreement Amen...
#      → AUTRES/
# [109/224] 5 - AbbVie IQVIA Global Master InfoLicandSvcs Agreement Amen...
#      → AUTRES/
# [110/224] 6 - IQVIA ABV Amendment 6 to ILSA.pdf...
#      → AUTRES/
# [111/224] 7 - Please_DocuSign_7th_Amendment_to_AbbVie_IQVIA ILSA Feb 2...
#      → AUTRES/
# [112/224] 8 - s-8th Amendment to AbbVie IQVIA ILSA_0215212.pdf...
#      → AUTRES/
# [113/224] 9 - Amendment to AbbVie and IQVIA Information Licensing & Se...
#      → AUTRES/
# [114/224] ABBOTT RAPID DIAGNOSTICS  -PRESENTATION OFFRES MS 2025.pdf...
#      → AUTRES/
# [115/224] ABBOTT RAPID DIAGNOSTICS  -PRESENTATION OFFRES MS 2025.pptx...
#      → AUTRES/
# [116/224] ABBVIE - IQVIA _ souscription XPONENT PARKINSON 2025-2026 - ...
#      → AUTRES/
# [117/224] Abbvie - Service Review Data du 06 Mars 2025.pptx...
#      → AUTRES/
# [118/224] ABBVIE - SOW 3213902- Tier 2 MDM Coordinator 2025.pdf...
#      → AUTRES/
# [119/224] ABBVIE - SOW 3213906- ABBVIE 2025 MDM Demand and A.pdf...
#      → AUTRES/
# [120/224] ABBVIE ALLERGAN IQVIA_Service Review OneKey 01 2025 VF.pptx...
#      → AUTRES/
# [121/224] ABBVIE ALLERGAN IQVIA_Service Review OneKey 04 2025 V1.pptx...
#      → AUTRES/
# [122/224] ABBVIE ALLERGAN IQVIA_Service Review OneKey 04 2025 V2.pptx...
#      → AUTRES/
# [123/224] ABBVIE ALLERGAN IQVIA_Service Review OneKey RDV du 08 avril ...
#      → AUTRES/
# [124/224] AbbVie ILSA MSA Amendment No. 16_Final - signed.pdf...
#      → AUTRES/
# [125/224] ABBVIE IQVIA _ souscription LTD immuno 6 mois - signé.pdf...
#      → AUTRES/
# [126/224] ABBVIE IQVIA _ SOW XPONENT IMMUNO - signé.pdf...
#      → AUTRES/
# [127/224] ABBVIE IQVIA _ veille concurrentielle Plusieurs aires thérap...
#      → AUTRES/
# [128/224] ABBVIE IQVIA _ Xponent hebdo retine 6 mois SOW signé.pdf...
#      → AUTRES/
# [129/224] ABBVIE SOW 3208828 MDM RSU Change Request - signed.pdf...
#      → AUTRES/
# [130/224] Accord - RNW OneKey 2025.pdf...
#      → AUTRES/
# [131/224] Alcon_Purchase Order_4200246579.pdf...
#      → AUTRES/
# [132/224] Alcon_Purchase Order_4200269461.pdf...
#      → AUTRES/
# [133/224] Avenant_1_Onekey_-_ABBOTT_France-modification_périmetre_OneK...
#      → AUTRES/
# [134/224] CC 801015A9 SOW 4202859904 - signed.pdf...
#      → AUTRES/
# [135/224] COMPAGNION IQVIA_ABBOTT dc.pdf...
#      → AUTRES/
# [136/224] Complete_with_Docusign_Change_Order_-_IQVIA_ - sig.pdf...
#      → AUTRES/
# [137/224] Complete_with_Docusign_IQVIA_SOW_Accord_Heal.pdf...
#      → AUTRES/
# [138/224] Complétez_avec_Docusign _3255485_ABBOTT_Rapi.pdf...
#      → AUTRES/
# [139/224] CONTRACT_305199 MASTER OFFICINE RNW 2024 - signé.pdf...
#      → AUTRES/
# [140/224] Contrat d_application_2025-FR-CA-CEXICE-00019 - signed.pdf...
#      → AUTRES/
# [141/224] Contrat d_application_2025-FR-CA-CEXICE-00021 SOW signé.pdf...
#      → AUTRES/
# [142/224] Contrat d_application_2025-FR-CA-CEXICE-00021_signed.pdf...
#      → AUTRES/
# [143/224] CSJ-CSJ00008437-Version 1 IQVIA MAI.pdf...
#      → AUTRES/
# [144/224] ENVOL_AbbVie-IQVIA Statement of Work_24032_final final clean...
#      → AUTRES/
# [145/224] IQVIA ABBVIE Incentive 360 - signé.pdf...
#      → AUTRES/
# [146/224] IQVIA ABBVIE _ avenant souscription globale IMMUNO - signé.p...
#      → AUTRES/
# [147/224] IQVIA ABBVIE _ avenant souscription globale IMMUNO.pdf...
#      → AUTRES/
# [148/224] Iqvia pour AA_Approches méthodologiques pour optimiser le ta...
#      → AUTRES/
# [149/224] Iqvia pour AA_Approches méthodologiques pour optimiser le ta...
#      → AUTRES/
# [150/224] Iqvia pour AA_Approches méthodologiques pour optimiser le ta...
#      → AUTRES/
# [151/224] Iqvia pour AA_Approches méthodologiques pour optimiser le ta...
#      → AUTRES/
# [152/224] Iqvia pour AA_Our methodology to optimize your marketing and...
#      → AUTRES/
# [153/224] Iqvia pour AA_Our methodology to optimize your marketing and...
#      → AUTRES/
# [154/224] Iqvia pour Abbvie - Service Review Data du 06 Mars 2025.pdf...
#      → AUTRES/
# [155/224] IQVIA pour ABBVIE Audit des spécialités prescriptrices H+V 2...
#      → AUTRES/
# [156/224] Iqvia pour Abbvie Reseau de pharmacies et données de vente_F...
#      → AUTRES/
# [157/224] Iqvia pour Abbvie_Xponent Spécialistes Performance Skyrizi R...
#      → AUTRES/
# [158/224] IQVIA_ABBVIE FR_Statement of Work_UPDATE_220912.pdf...
#      → AUTRES/
# [159/224] LO_OTHERS_11 - AbbVie_ILSA AMENDMENT 11 for 90days Apr2023  ...
#      → AUTRES/
# [160/224] Meeting 22 01 25_Comment optimiser vos approches en pharmaci...
#      → AUTRES/
# [161/224] MSA_ABBOTT  PT 60 days.pdf...
#      → AUTRES/
# [162/224] Order81009176 - Xponent SPE 2025.pdf...
#      → AUTRES/
# [163/224] Order81009177 - Pharmatrend 2025.pdf...
#      → AUTRES/
# [164/224] Order81009178 - MasterOfficine 2025.pdf...
#      → AUTRES/
# [165/224] Order81009182 - LTD national 2025.pdf...
#      → AUTRES/
# [166/224] Order81009183 - LTD sectoriel 2025.pdf...
#      → AUTRES/
# [167/224] Order81009283.pdf...
#      → AUTRES/
# [168/224] Order81009286.pdf...
#      → AUTRES/
# [169/224] Order81009484 - LTD base active sectorielle.pdf...
#      → AUTRES/
# [170/224] Order81009486.pdf...
#      → AUTRES/
# [171/224] OrderForm_Abbott_DC_IQVIA_3181844_suivi_Nat_FSL2_20252026_-_...
#      → AUTRES/
# [172/224] OrderForm_Abbott_DC_IQVIA_3181845_suivi_FSL_dataset_au_secte...
#      → AUTRES/
# [173/224] OrderForm_Abbott_DC_IQVIA__2921149_Xponent_Review_Clean_Vers...
#      → AUTRES/
# [174/224] PO 6800104575 - CRM IQVIA running fees FR.pdf...
#      → AUTRES/
# [175/224] PO global abbvie  3224285.pdf...
#      → AUTRES/
# [176/224] PO IQVIA 15005848 2025.pdf...
#      → AUTRES/
# [177/224] PO IQVIA PO4202772643.PDF...
#      → AUTRES/
# [178/224] PO.pdf...
#      → AUTRES/
# [179/224] PO4201992624.PDF...
#      → AUTRES/
# [180/224] PO4202208060.PDF...
#      → AUTRES/
# [181/224] PO4202456147.pdf...
#      → AUTRES/
# [182/224] PO4202462949.PDF...
#      → AUTRES/
# [183/224] PO4202708943 XPONENT RETINE HEBDO.PDF...
#      → AUTRES/
# [184/224] PO4202708952 IQVIA XPONENT PARKINSON.PDF...
#      → MEDICAL_NEUROLOGIE/ (Parkinson)
# [185/224] PO4202712637.PDF...
#      → AUTRES/
# [186/224] PO4202714071.PDF...
#      → AUTRES/
# [187/224] PO4202714074 LTD immuno.PDF...
#      → AUTRES/
# [188/224] PO4202715085.PDF...
#      → AUTRES/
# [189/224] PO4202715086.PDF...
#      → AUTRES/
# [190/224] PO4202718278.PDF...
#      → AUTRES/
# [191/224] PO4202719098 revu prolongation hebdo (002).pdf...
#      → AUTRES/
# [192/224] PO4202719098 Xponent Immuno avec extension hebdo modified.pd...
#      → AUTRES/
# [193/224] PO4202719098 Xponent Immuno avec extension hebdo.PDF...
#      → AUTRES/
# [194/224] PO4202719098 xponent immuno.PDF...
#      → AUTRES/
# [195/224] PO4202719124.PDF...
#      → AUTRES/
# [196/224] PO4202721538.PDF...
#      → AUTRES/
# [197/224] PO4202723413.PDF...
#      → AUTRES/
# [198/224] PO4202727582.PDF...
#      → AUTRES/
# [199/224] PO4202752939.PDF...
#      → AUTRES/
# [200/224] PO4202788740.PDF...
#      → AUTRES/
# [201/224] PO4202808769.PDF...
#      → AUTRES/
# [202/224] PO4202811316_Channel Dynamics LLC_2025.pdf...
#      → AUTRES/
# [203/224] PO4202812717_Channel Dynamics DLBCL_2025.pdf...
#      → MEDICAL_ONCOLOGIE/ (DLBCL)
# [204/224] PO4202859904.PDF...
#      → AUTRES/
# [205/224] PROPOSAL_ABBVIE_UPDATE_V2.0_20220713.pdf...
#      → AUTRES/
# [206/224] SOW Abbott_DC_IQVIA 2023 2024 2025 __2936495_ONEKEY.pdf...
#      → AUTRES/
# [207/224] SOW Abbvie.pdf...
#      → AUTRES/
# [208/224] SOW_IQVIA_3214140_Pharmatrend Ventes Sell out sell Pharmacie...
#      → AUTRES/
# [209/224] XXXX_IQVIA pour ABOCA - Ajustement de sectoriation 2025.pptx...
#      → AUTRES/
# [210/224] _Abbott_IQVIA Fully Executed MSA 1.3.23.pdf...
#      → AUTRES/
# [211/224] _Xponent_Review_contrat_trois_ans 2023_2025.pdf...
#      → AUTRES/
# [212/224] ~$3047384_IQVIA pour ABBOTT DC_Suivi COHORTES pharmacies 202...
#      → AUTRES/
# [213/224] ~$3181844 _IQVIA pour ABBOTT DC_Suivi national du FSL2 par s...
#      → MEDICAL_DIABETOLOGIE/ (diabète)
# [214/224] ~$3181845_IQVIA pour Abbott DC_Suivi FSL Dataset au secteur ...
#      → AUTRES/
# [215/224] ~$3201575_IQVIA pour AbbVie_RNW Veille promotionnelle 2025.p...
#      → AUTRES/
# [216/224] ~$3225553 - Proposition commerciale pour ABBVIE - LTD Immuno...
#      → AUTRES/
# [217/224] ~$3234632_IQVIA pour Abbott DC_Suivi FSL LTD & Dataset - Ajo...
#      → AUTRES/
# [218/224] ~$3236804_IQVIA pour ABBOTT DC_Suivi COHORTES pharmacies 202...
#      → AUTRES/
# [219/224] ~$ABBVIE ALLERGAN IQVIA_Service Review OneKey 01 2025 VF.ppt...
#      → AUTRES/
# [220/224] ~$ABBVIE ALLERGAN IQVIA_Service Review OneKey 04 2025 V1.ppt...
#      → AUTRES/
# [221/224] ~$ABBVIE ALLERGAN IQVIA_Service Review OneKey RDV du 08 avri...
#      → AUTRES/
# [222/224] ~$Iqvia pour AA_Approches méthodologiques pour optimiser le ...
#      → AUTRES/
# [223/224] ~$Iqvia pour AA_Our methodology to optimize your marketing a...
#      → AUTRES/
# [224/224] ~$Meeting 22 01 25_Comment optimiser vos approches en pharma...
#      → AUTRES/
#
# 📊 RÉSULTATS: 9/224 fichiers médicaux classés
#
# 📝 PHASE 4: Génération du rapport...
# --------------------------------------------------
# ✅ Rapport sauvé: C:\Users\kosmo\pycode\Iqvia_process\Depots\RAPPORT_SIMPLE.md
#
# 🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉
# ✅ TERMINÉ - Même résultat qu'avec LangGraph !
# 💡 90% moins de code, même performance
# 🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉

# %%
! pip install -U langgraph langsmith
! pip install langchain_community
! pip install langchain_openai

# %%
import os
from langchain_openai import ChatOpenAI  #  
# API Key
os.environ['OPENAI_API_KEY'] = "sk-proj-rPBnsXim 0yG78BbewkjRBfeT3BlbkFJoLeEVAbOl0kiGIZTWPKAtav6nWikZPSewB3oeo055nFcLW9rnMorepgfeAZNQQz5FUUwrtmQsA"

# Model
llm = ChatOpenAI(
    model="gpt-4o-mini",  #  
    temperature=0.2
)

# %%
from crewai import Agent, Task, Crew, Process
from langchain_openai import ChatOpenAI
import os

# Configuration du modèle LLM
# os.environ["OPENAI_API_KEY"] = "votre-clé-api"
llm = ChatOpenAI(model="gpt-4", temperature=0.2)

# Définition des descriptions de tags exactement comme dans le prompt initial
SALES_DESCRIPTION = """
#sales = This tag is used when a user asks questions about Sales Performance. 
Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices) 
and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
"""

SALES_EXAMPLES = """
Examples of #sales questions:
1. What is the trend of our product performance over the last quarter?
2. How does our revenue compare across different countries?
3. Which anatomical therapy class is generating the most revenue?
4. What are the top-performing products in the public/pharmacy price segment?
5. How do our sales figures vary by product form and strength?
6. What is the market share of our corporation in the European region?
7. How do sales figures differ between wholesalers and manufacturers?
8. What is the average price point for our products in the US market?
9. Which disease category is driving the highest sales for our company?
10. How have our sales figures changed year-over-year in the UK?
"""

CHANNEL_DYNAMICS_DESCRIPTION = """
#Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend, 
Marketing Spend, Promoter/detractors, Mentions etc. 
The data provides information on how products are marketed and percieved.
"""

CHANNEL_DYNAMICS_EXAMPLES = """
Examples of #Channel_Dynamics questions:
1. What is the current sentiment around my brand in social media discussions?
2. How does our marketing spend compare to industry benchmarks?
3. What are the key factors influencing customer perceptions of our products?
4. How many positive reviews have we received in the last quarter?
5. What channels are driving the most engagement for our marketing campaigns?
6. How frequently are our products mentioned in online forums?
7. What is the average customer rating for our latest product launch?
8. How do our promotional efforts impact customer loyalty?
9. What trends are emerging in consumer feedback about our brand?
10. How does our brand's visibility compare to that of our main competitors?
"""

def classify_intent(question, verbose=True):
    """
    Fonction principale qui prend une question en entrée et renvoie l'intention classifiée
    
    Args:
        question (str): La question de l'utilisateur
        verbose (bool): Afficher les détails d'exécution
        
    Returns:
        str: L'intention classifiée (#sales, #Channel_Dynamics, ou #somewhereelse)
    """
    if verbose:
        print(f"Classifying intent for question: {question}")
    
    # Définition des agents
    question_analyzer = Agent(
        role="Question Analyzer",
        goal="Extract the most relevant information from user questions to determine their intent",
        backstory="""You are an expert in natural language processing and intent classification.
        Your specialty is understanding the nuances of business questions and extracting key elements
        that reveal the true intent behind them.""",
        verbose=True,
        allow_delegation=False,
        llm=llm
    )

    tag_expert = Agent(
        role="Tag Description Expert",
        goal="Analyze tag descriptions to understand their scope and relevant dimensions",
        backstory="""You have extensive knowledge of business intelligence taxonomy and categorization.
        You excel at understanding tag descriptions and identifying the key dimensions, data points,
        and business goals that each tag encompasses.""",
        verbose=True,
        allow_delegation=False,
        llm=llm
    )

    correlation_analyst = Agent(
        role="Correlation Analyst",
        goal="Determine the best matching hashtag for user questions by analyzing correlations",
        backstory="""You are a data correlation specialist with a strong background in semantic analysis.
        Your expertise lies in finding patterns and connections between user questions and predefined
        taxonomies to ensure accurate classification.""",
        verbose=True,
        allow_delegation=False,
        llm=llm
    )

    # Définition des tâches
    analyze_question_task = Task(
        description=f"""
        Step 1: Read the user question carefully and extract the most relevant information.
        
        Question to analyze: {question}
        
        Focus on:
        - What type of data the user is asking about
        - What dimensions they're interested in
        - What business goal they're trying to achieve
        
        Provide a detailed analysis of the question highlighting these elements.
        """,
        agent=question_analyzer,
        expected_output="A comprehensive analysis of the user question with key elements highlighted"
    )

    analyze_tags_task = Task(
        description=f"""
        Step 2: Analyze the tag descriptions thoroughly:
        
        {SALES_DESCRIPTION}
        {SALES_EXAMPLES}
        
        {CHANNEL_DYNAMICS_DESCRIPTION}
        {CHANNEL_DYNAMICS_EXAMPLES}
        
        Extract and list:
        - The main business goals associated with each tag
        - The key data points covered by each tag
        - The dimensions that each tag encompasses
        
        Provide a detailed comparison of the two tags based on your analysis.
        """,
        agent=tag_expert,
        expected_output="A detailed analysis of both tag descriptions with key elements highlighted and compared"
    )

    determine_correlation_task = Task(
        description=f"""
        Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
        
        User Question: {question}
        
        Tag Descriptions:
        {SALES_DESCRIPTION}
        {CHANNEL_DYNAMICS_DESCRIPTION}
        
        Compare the elements of the question with the characteristics of each tag.
        Look for strong correlations between:
        - The question's focus and the tag's scope
        - The dimensions mentioned in the question and those covered by the tag
        - The implicit business goal of the question and the goals associated with the tag
        
        Classify the question as either:
        - #sales
        - #Channel_Dynamics
        - #somewhereelse (if it doesn't clearly match either of the first two)
        
        Provide a confidence score (0-100%) and explain your reasoning.
        """,
        agent=correlation_analyst,
        expected_output="A classification decision with confidence score and detailed reasoning"
    )

    # Création du crew
    intent_classification_crew = Crew(
        agents=[question_analyzer, tag_expert, correlation_analyst],
        tasks=[analyze_question_task, analyze_tags_task, determine_correlation_task],
        verbose=True,
        process=Process.sequential
    )
    
    # Exécution du crew
    result = intent_classification_crew.kickoff()
    
    # Extraction de la classification à partir du résultat
    final_result = result.raw
    
    # Analyse de la réponse pour extraire le tag
    if "#sales" in final_result.lower():
        return "#sales"
    elif "#channel_dynamics" in final_result.lower():
        return "#Channel_Dynamics"
    else:
        return "#somewhereelse"

# Exemple d'utilisation
if __name__ == "__main__":
    # Import nécessaire pour pandas
    import pandas as pd
    from IPython.display import display
    
    # Exemples de questions à tester
    questions = [
        "What are the top three competitors in my market and their marketing strategies",
        "How can I improve my product's features to better meet customer needs",
        "What pricing strategy would maximize my profit margins",
        "What distribution channels should I consider for my product",
        "How do our sales figures compare to those of our main competitors?",
        "How does the performance of our products differ by pack size?",
        "How does the sales performance of our new products compare to established ones?",
        "How many mentions is my product getting?",
        "What are my competitors spending on marketing?"
    ]
    
    # Collecter les résultats
    results = []
    for question in questions:
        intent = classify_intent(question, verbose=False)
        results.append({"Question": question, "Intent": intent})
        print(f"Question: {question}")
        print(f"Intent: {intent}")
        print("-" * 80)
    
    # Créer un DataFrame pandas
    df_results = pd.DataFrame(results)
    
    # Afficher le DataFrame avec un style sombre (comme dans la capture d'écran)
    def highlight_intent(val):
        if val == "#sales":
            return 'background-color: #e8f5e9; color: #2e7d32; font-weight: bold'
        elif val == "#Channel_Dynamics":
            return 'background-color: #e3f2fd; color: #1565c0; font-weight: bold'
        else:
            return 'background-color: #fff8e1; color: #f9a825; font-weight: bold'
    
    # Style pour tout le DataFrame (fond sombre)
    def style_df(df):
        # Style pour tout le DataFrame
        styles = [
            dict(selector="th", props=[("background-color", "#333"), 
                                       ("color", "white"),
                                       ("font-weight", "bold"),
                                       ("text-align", "center")]),
            dict(selector="td", props=[("text-align", "right"),
                                      ("padding", "10px 15px")]),
            dict(selector="tr:nth-child(even)", props=[("background-color", "#2a2a2a")]),
            dict(selector="tr:nth-child(odd)", props=[("background-color", "#222")]),
            dict(selector="", props=[("background-color", "#1a1a1a"),
                                     ("color", "white"),
                                     ("border", "none")])
        ]
        return styles
    
    try:
        # Essayer d'appliquer le style complet
        styled_df = df_results.style.set_table_styles(style_df(df_results)).applymap(highlight_intent, subset=['Intent'])
        display(styled_df)
    except:
        # Version simple si le style complet échoue
        try:
            styled_df = df_results.style.applymap(highlight_intent, subset=['Intent'])
            display(styled_df)
        except:
            # Affichage brut en dernier recours
            print("\nTableau pandas (non stylisé):")
            print(df_results)
# Out:
# Overriding of current TracerProvider is not allowed
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# # Agent: Question Analyzer
# ## Task:
#         Step 1: Read the user question carefully and extract the most relevant information.
#
#         Question to analyze: What are the top three competitors in my market and their marketing strategies
#
#         Focus on:
#         - What type of data the user is asking about
#         - What dimensions they're interested in
#         - What business goal they're trying to achieve
#
#         Provide a detailed analysis of the question highlighting these elements.
#
#
#
# # Agent: Question Analyzer
# ## Final Answer:
# The user's question pertains to competitive analysis within their specific market. They are interested in identifying the top three competitors and gaining insights into their marketing strategies. The intent behind this question suggests a need to understand the competitive landscape better, possibly to inform their own marketing strategy, identify market gaps, or keep abreast of industry trends and practices.
#
#
# # Agent: Tag Description Expert
# ## Task:
#         Step 2: Analyze the tag descriptions thoroughly:
#
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# Examples of #sales questions:
# 1. What is the trend of our product performance over the last quarter?
# 2. How does our revenue compare across different countries?
# 3. Which anatomical therapy class is generating the most revenue?
# 4. What are the top-performing products in the public/pharmacy price segment?
# 5. How do our sales figures vary by product form and strength?
# 6. What is the market share of our corporation in the European region?
# 7. How do sales figures differ between wholesalers and manufacturers?
# 8. What is the average price point for our products in the US market?
# 9. Which disease category is driving the highest sales for our company?
# 10. How have our sales figures changed year-over-year in the UK?
#
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
# Examples of #Channel_Dynamics questions:
# 1. What is the current sentiment around my brand in social media discussions?
# 2. How does our marketing spend compare to industry benchmarks?
# 3. What are the key factors influencing customer perceptions of our products?
# 4. How many positive reviews have we received in the last quarter?
# 5. What channels are driving the most engagement for our marketing campaigns?
# 6. How frequently are our products mentioned in online forums?
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# Main business goals:
# - #sales: Maximizing sales
# - #Channel_Dynamics: Optimizing marketing spend and improving brand perception
#
# Key data points:
# - #sales: Sales information in various currencies, trade levels, sales split by several dimensions
# - #Channel_Dynamics: Spend (general and marketing), promoter/detractors, mentions
#
# Dimensions:
# - #sales: Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, Pack
# - #Channel_Dynamics: Marketing channels, customer sentiment, brand visibility
#
# Comparison:
# - #sales is more internally focused, providing insights into sales performance across different markets and segments
# - #Channel_Dynamics is more externally focused, providing insights into market perception of the business and its products, and helping optimize marketing strategies.
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: What are the top three competitors in my market and their marketing strategies
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
# Overriding of current TracerProvider is not allowed
# # Agent: Correlation Analyst
# ## Final Answer:
# The best matching tag for the user question "What are the top three competitors in my market and their marketing strategies" is #Channel_Dynamics. This decision is based on the correlation between the user's question about competitors' marketing strategies and the #Channel_Dynamics tag's focus on marketing spend, brand perception, and product marketing. The confidence score for this classification is 90% due to the strong alignment between the question's focus on marketing strategies and the tag's scope.
#
#
# Question: What are the top three competitors in my market and their marketing strategies
# Intent: #Channel_Dynamics
# --------------------------------------------------------------------------------
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# # Agent: Question Analyzer
# ## Task:
#         Step 1: Read the user question carefully and extract the most relevant information.
#
#         Question to analyze: How can I improve my product's features to better meet customer needs
#
#         Focus on:
#         - What type of data the user is asking about
#         - What dimensions they're interested in
#         - What business goal they're trying to achieve
#
#         Provide a detailed analysis of the question highlighting these elements.
#
#
#
# # Agent: Question Analyzer
# ## Final Answer:
# The user's question is centered around the improvement of product features to better align with customer needs. The data they are interested in involves understanding customer needs, which can be gathered through various methods such as customer surveys, reviews, and user testing. They are interested in the dimensions of product features and customer satisfaction, indicating a focus on improving the product based on customer feedback and enhancing customer experience. The underlying business goal is to improve the product, which will likely lead to increased customer satisfaction and potentially business growth.
#
#
# # Agent: Tag Description Expert
# ## Task:
#         Step 2: Analyze the tag descriptions thoroughly:
#
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# Examples of #sales questions:
# 1. What is the trend of our product performance over the last quarter?
# 2. How does our revenue compare across different countries?
# 3. Which anatomical therapy class is generating the most revenue?
# 4. What are the top-performing products in the public/pharmacy price segment?
# 5. How do our sales figures vary by product form and strength?
# 6. What is the market share of our corporation in the European region?
# 7. How do sales figures differ between wholesalers and manufacturers?
# 8. What is the average price point for our products in the US market?
# 9. Which disease category is driving the highest sales for our company?
# 10. How have our sales figures changed year-over-year in the UK?
#
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
# Examples of #Channel_Dynamics questions:
# 1. What is the current sentiment around my brand in social media discussions?
# 2. How does our marketing spend compare to industry benchmarks?
# 3. What are the key factors influencing customer perceptions of our products?
# 4. How many positive reviews have we received in the last quarter?
# 5. What channels are driving the most engagement for our marketing campaigns?
# 6. How frequently are our products mentioned in online forums?
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# The #sales tag is primarily associated with the business goal of maximizing sales, covering data points such as sales in various currencies, trade levels, and market share. It encompasses dimensions like Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, and Pack.
#
# On the other hand, the #Channel_Dynamics tag is associated with the business goal of understanding and improving product perception. It covers data points like marketing spend, sentiment analysis, customer reviews, and product mentions, and encompasses dimensions like marketing channels, customer ratings, promotional efforts, and brand visibility.
#
# In comparison, #sales focuses on hard sales data and performance, while #Channel_Dynamics deals with product perception and visibility. Both tags serve different but equally important roles in a business's growth and success.
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: How can I improve my product's features to better meet customer needs
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
# Overriding of current TracerProvider is not allowed
# # Agent: Correlation Analyst
# ## Final Answer:
# The best matching tag for the user question "How can I improve my product's features to better meet customer needs" is #Channel_Dynamics. I am 85% confident in this classification. The reasoning behind this is that the user's question is more about understanding customer needs and improving product perception, which aligns with the #Channel_Dynamics tag's focus on product perception and visibility. The #sales tag, on the other hand, is more focused on sales performance and data, which doesn't directly relate to the user's question.
#
#
# Question: How can I improve my product's features to better meet customer needs
# Intent: #sales
# --------------------------------------------------------------------------------
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# # Agent: Question Analyzer
# ## Task:
#         Step 1: Read the user question carefully and extract the most relevant information.
#
#         Question to analyze: What pricing strategy would maximize my profit margins
#
#         Focus on:
#         - What type of data the user is asking about
#         - What dimensions they're interested in
#         - What business goal they're trying to achieve
#
#         Provide a detailed analysis of the question highlighting these elements.
#
#
#
# # Agent: Question Analyzer
# ## Final Answer:
# The user's question is about pricing strategies, specifically those that could help maximize profit margins. This implies they are seeking a method to increase the gap between the cost of production and the selling price of their product or service. The user's intent is to enhance profitability, likely within a business context. They may also be interested in exploring the effects of various pricing strategies on their overall profit.
#
#
# # Agent: Tag Description Expert
# ## Task:
#         Step 2: Analyze the tag descriptions thoroughly:
#
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# Examples of #sales questions:
# 1. What is the trend of our product performance over the last quarter?
# 2. How does our revenue compare across different countries?
# 3. Which anatomical therapy class is generating the most revenue?
# 4. What are the top-performing products in the public/pharmacy price segment?
# 5. How do our sales figures vary by product form and strength?
# 6. What is the market share of our corporation in the European region?
# 7. How do sales figures differ between wholesalers and manufacturers?
# 8. What is the average price point for our products in the US market?
# 9. Which disease category is driving the highest sales for our company?
# 10. How have our sales figures changed year-over-year in the UK?
#
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
# Examples of #Channel_Dynamics questions:
# 1. What is the current sentiment around my brand in social media discussions?
# 2. How does our marketing spend compare to industry benchmarks?
# 3. What are the key factors influencing customer perceptions of our products?
# 4. How many positive reviews have we received in the last quarter?
# 5. What channels are driving the most engagement for our marketing campaigns?
# 6. How frequently are our products mentioned in online forums?
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# The main business goals associated with each tag are as follows:
#
# #sales: The primary business goal is to maximize sales performance. This involves understanding and optimizing various aspects of sales, including trends, revenue comparisons, product performance, market share, and pricing strategies across different trade levels and geographical locations.
#
# #Channel_Dynamics: The main business goal is to understand and optimize marketing efforts and brand perception. This includes analyzing marketing spend, customer sentiment, brand visibility, customer reviews, and the impact of promotional efforts on customer loyalty.
#
# The key data points covered by each tag are:
#
# #sales: Sales data in various currencies, trade levels (Manufacturer, Wholesaler, Public/pharmacy prices), country-specific data, corporation-specific data, data related to Anatomical Therapy Class, Disease, Product, Form, Strength, and Pack.
#
# #Channel_Dynamics: Data related to marketing spend, promoter/detractors, mentions, and customer sentiment.
#
# The dimensions that each tag encompasses are:
#
# #sales: Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, Pack.
#
# #Channel_Dynamics: Channels of marketing, customer perceptions, brand visibility, customer loyalty, and trends in consumer feedback.
#
# Comparison of the two tags:
#
# #sales focuses on the performance of sales, including trends, revenue, and market share. It deals with hard data and quantitative aspects of sales. It is more focused on internal data and direct business outcomes.
#
# #Channel_Dynamics, on the other hand, deals with the perception of the brand and the effectiveness of marketing efforts. It involves both quantitative (marketing spend, mentions) and qualitative data (customer sentiment, reviews). It is more focused on external data and indirect business outcomes.
#
# In the context of the user's question about pricing strategies to maximize profit margins, both tags could potentially be relevant. The #sales tag could provide insights into how different pricing strategies have impacted sales performance in the past, while the #Channel_Dynamics tag could provide insights into how these strategies have affected brand perception and customer sentiment.
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: What pricing strategy would maximize my profit margins
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
# Overriding of current TracerProvider is not allowed
# # Agent: Correlation Analyst
# ## Final Answer:
# The user's question "What pricing strategy would maximize my profit margins" is best matched with the #sales tag. I am 85% confident in this classification. The question is directly related to sales performance and pricing strategies, which are key elements of the #sales tag. While the #Channel_Dynamics tag could potentially provide insights into how pricing strategies affect brand perception, the user's question does not explicitly mention these elements, making the #sales tag a stronger match.
#
#
# Question: What pricing strategy would maximize my profit margins
# Intent: #sales
# --------------------------------------------------------------------------------
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# # Agent: Question Analyzer
# ## Task:
#         Step 1: Read the user question carefully and extract the most relevant information.
#
#         Question to analyze: What distribution channels should I consider for my product
#
#         Focus on:
#         - What type of data the user is asking about
#         - What dimensions they're interested in
#         - What business goal they're trying to achieve
#
#         Provide a detailed analysis of the question highlighting these elements.
#
#
#
# # Agent: Question Analyzer
# ## Final Answer:
# The user's question pertains to marketing strategies, specifically distribution channels for a product. They are interested in exploring different avenues to distribute their product to reach their customers effectively. The underlying business goal is to maximize product reach, increase sales, and facilitate business growth. They may be seeking data on various types of distribution channels, their effectiveness, cost, reach, and how suitable they are for the user's specific product.
#
#
# # Agent: Tag Description Expert
# ## Task:
#         Step 2: Analyze the tag descriptions thoroughly:
#
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# Examples of #sales questions:
# 1. What is the trend of our product performance over the last quarter?
# 2. How does our revenue compare across different countries?
# 3. Which anatomical therapy class is generating the most revenue?
# 4. What are the top-performing products in the public/pharmacy price segment?
# 5. How do our sales figures vary by product form and strength?
# 6. What is the market share of our corporation in the European region?
# 7. How do sales figures differ between wholesalers and manufacturers?
# 8. What is the average price point for our products in the US market?
# 9. Which disease category is driving the highest sales for our company?
# 10. How have our sales figures changed year-over-year in the UK?
#
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
# Examples of #Channel_Dynamics questions:
# 1. What is the current sentiment around my brand in social media discussions?
# 2. How does our marketing spend compare to industry benchmarks?
# 3. What are the key factors influencing customer perceptions of our products?
# 4. How many positive reviews have we received in the last quarter?
# 5. What channels are driving the most engagement for our marketing campaigns?
# 6. How frequently are our products mentioned in online forums?
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# The main business goals associated with each tag are as follows:
#
# #sales: The primary business goal is to maximize sales performance. This involves understanding trends in product performance, comparing revenue across different countries, identifying top-performing products, and analyzing sales figures by product form and strength. It also includes understanding the market share of the corporation in different regions and the average price point for products in different markets.
#
# #Channel_Dynamics: The main business goal is to understand and optimize marketing spend and product perception. This includes understanding brand sentiment in social media discussions, comparing marketing spend to industry benchmarks, identifying key factors influencing customer perceptions, and tracking the number of positive reviews. It also involves understanding the channels driving the most engagement for marketing campaigns and the frequency of product mentions in online forums.
#
# The key data points covered by each tag are as follows:
#
# #sales: Data points include sales in various currencies, trade levels (Manufacturer, Wholesaler, Public/pharmacy prices), and sales figures split by dimensions such as Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, and Pack.
#
# #Channel_Dynamics: Data points include any kind of Spend, Marketing Spend, Promoter/detractors, Mentions, and information on how products are marketed and perceived.
#
# The dimensions that each tag encompasses are as follows:
#
# #sales: Dimensions include Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, and Pack.
#
# #Channel_Dynamics: Dimensions include different marketing channels, customer perceptions, brand visibility, and promotional efforts.
#
# In comparison, the #sales tag focuses on the performance of sales, including trends, revenue comparison, top-performing products, and sales figures by product form and strength. It also looks at market share and average price points. On the other hand, the #Channel_Dynamics tag focuses on marketing spend and product perception, including brand sentiment, marketing spend comparison, key factors influencing customer perceptions, and tracking positive reviews. It also looks at marketing engagement channels and product mention frequency. While both tags are crucial for a business, they focus on different aspects of business performance and strategy.
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: What distribution channels should I consider for my product
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
# Overriding of current TracerProvider is not allowed
# # Agent: Correlation Analyst
# ## Final Answer:
# The best matching hashtag for the user question "What distribution channels should I consider for my product" is #Channel_Dynamics. I am 85% confident in this classification. The question is more aligned with the scope of the #Channel_Dynamics tag, as it pertains to marketing and product placement strategies, rather than sales performance or data. The user is seeking advice on distribution channels, which is a key aspect of marketing and falls under the purview of the #Channel_Dynamics tag.
#
#
# Question: What distribution channels should I consider for my product
# Intent: #Channel_Dynamics
# --------------------------------------------------------------------------------
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# # Agent: Question Analyzer
# ## Task:
#         Step 1: Read the user question carefully and extract the most relevant information.
#
#         Question to analyze: How do our sales figures compare to those of our main competitors?
#
#         Focus on:
#         - What type of data the user is asking about
#         - What dimensions they're interested in
#         - What business goal they're trying to achieve
#
#         Provide a detailed analysis of the question highlighting these elements.
#
#
#
# # Agent: Question Analyzer
# ## Final Answer:
# The user's question is focused on the comparison of their company's sales figures with those of their main competitors. This indicates that the user is interested in sales data, particularly in a comparative context. The dimensions they're interested in involve their own company and their main competitors. The underlying business goal, while not explicitly stated, could be manifold: they might be trying to identify areas where they can improve, strategize their sales and marketing efforts more effectively, or simply understand their overall performance in the market.
#
#
# # Agent: Tag Description Expert
# ## Task:
#         Step 2: Analyze the tag descriptions thoroughly:
#
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# Examples of #sales questions:
# 1. What is the trend of our product performance over the last quarter?
# 2. How does our revenue compare across different countries?
# 3. Which anatomical therapy class is generating the most revenue?
# 4. What are the top-performing products in the public/pharmacy price segment?
# 5. How do our sales figures vary by product form and strength?
# 6. What is the market share of our corporation in the European region?
# 7. How do sales figures differ between wholesalers and manufacturers?
# 8. What is the average price point for our products in the US market?
# 9. Which disease category is driving the highest sales for our company?
# 10. How have our sales figures changed year-over-year in the UK?
#
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
# Examples of #Channel_Dynamics questions:
# 1. What is the current sentiment around my brand in social media discussions?
# 2. How does our marketing spend compare to industry benchmarks?
# 3. What are the key factors influencing customer perceptions of our products?
# 4. How many positive reviews have we received in the last quarter?
# 5. What channels are driving the most engagement for our marketing campaigns?
# 6. How frequently are our products mentioned in online forums?
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# The main business goals associated with each tag are as follows:
#
# #sales: The primary business goal is to maximize sales and understand sales performance. This could involve identifying top-performing products, understanding market share, and comparing revenue across different countries and trade levels.
#
# #Channel_Dynamics: The main business goal is to understand and optimize marketing efforts. This could involve analyzing customer sentiment, comparing marketing spend to industry benchmarks, and understanding the impact of promotional efforts on customer loyalty.
#
# The key data points covered by each tag are:
#
# #sales: Sales in various currencies, trade levels (Manufacturer, Wholesaler, Public/pharmacy prices), and market share.
#
# #Channel_Dynamics: Marketing spend, promoter/detractors, mentions, and customer reviews.
#
# The dimensions that each tag encompasses are:
#
# #sales: Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, Pack.
#
# #Channel_Dynamics: Brand sentiment, marketing channels, customer perceptions, and brand visibility.
#
# Comparing the two tags, #sales is more focused on the quantitative aspects of business performance, specifically related to sales and revenue. It provides a detailed breakdown of sales performance across various dimensions, allowing for a comprehensive understanding of where and how sales are being generated.
#
# On the other hand, #Channel_Dynamics is more qualitative, focusing on the perception and visibility of the brand. It provides insights into how marketing efforts are being received and perceived, which channels are most effective, and how the brand is being discussed and rated by customers.
#
# In the context of the user's question, both tags could be relevant. #sales could provide the necessary data to compare their company's sales figures with those of their main competitors. #Channel_Dynamics could provide insights into how their marketing efforts and brand perception compare to their competitors, which could indirectly influence sales figures.
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: How do our sales figures compare to those of our main competitors?
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
# Overriding of current TracerProvider is not allowed
# # Agent: Correlation Analyst
# ## Final Answer:
# The best matching hashtag for the user question "How do our sales figures compare to those of our main competitors?" is #sales. I am 90% confident in this classification. The question is directly asking about sales figures, which falls under the scope of the #sales tag. The tag's focus on understanding and maximizing sales performance, as well as its coverage of data points such as sales in various currencies and trade levels, aligns well with the user's question. The question does not mention any elements related to the #Channel_Dynamics tag, such as marketing spend or brand perception. Therefore, the #sales tag is the most appropriate classification.
#
#
# Question: How do our sales figures compare to those of our main competitors?
# Intent: #sales
# --------------------------------------------------------------------------------
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# # Agent: Question Analyzer
# ## Task:
#         Step 1: Read the user question carefully and extract the most relevant information.
#
#         Question to analyze: How does the performance of our products differ by pack size?
#
#         Focus on:
#         - What type of data the user is asking about
#         - What dimensions they're interested in
#         - What business goal they're trying to achieve
#
#         Provide a detailed analysis of the question highlighting these elements.
#
#
#
# # Agent: Question Analyzer
# ## Final Answer:
# The user is seeking data on the performance of their products, with a specific interest in how this performance varies by pack size. They are likely looking to optimize their product offerings based on this data, potentially making decisions about which pack sizes to promote, continue offering, or discontinue. The performance data they're interested in could encompass a range of metrics, including sales volume, revenue, customer satisfaction, or product usage.
#
#
# # Agent: Tag Description Expert
# ## Task:
#         Step 2: Analyze the tag descriptions thoroughly:
#
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# Examples of #sales questions:
# 1. What is the trend of our product performance over the last quarter?
# 2. How does our revenue compare across different countries?
# 3. Which anatomical therapy class is generating the most revenue?
# 4. What are the top-performing products in the public/pharmacy price segment?
# 5. How do our sales figures vary by product form and strength?
# 6. What is the market share of our corporation in the European region?
# 7. How do sales figures differ between wholesalers and manufacturers?
# 8. What is the average price point for our products in the US market?
# 9. Which disease category is driving the highest sales for our company?
# 10. How have our sales figures changed year-over-year in the UK?
#
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
# Examples of #Channel_Dynamics questions:
# 1. What is the current sentiment around my brand in social media discussions?
# 2. How does our marketing spend compare to industry benchmarks?
# 3. What are the key factors influencing customer perceptions of our products?
# 4. How many positive reviews have we received in the last quarter?
# 5. What channels are driving the most engagement for our marketing campaigns?
# 6. How frequently are our products mentioned in online forums?
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# The main business goals associated with each tag are as follows:
#
# #sales: The primary business goal is to maximize sales and understand sales performance. This could involve identifying top-performing products, understanding market share, and analyzing sales trends over time.
#
# #Channel_Dynamics: The main business goal is to understand and optimize marketing efforts. This could involve analyzing customer sentiment, comparing marketing spend to industry benchmarks, and understanding the impact of promotional efforts on customer loyalty.
#
# The key data points covered by each tag are as follows:
#
# #sales: The data points include sales in various currencies, trade levels (Manufacturer, Wholesaler, Public/pharmacy prices), and sales figures split by various dimensions.
#
# #Channel_Dynamics: The data points include marketing spend, promoter/detractor metrics, brand mentions, and customer sentiment.
#
# The dimensions that each tag encompasses are as follows:
#
# #sales: The dimensions include Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, and Pack.
#
# #Channel_Dynamics: The dimensions are not explicitly mentioned in the tag description, but could potentially include marketing channels, customer segments, product categories, and time periods.
#
# Comparing the two tags, #sales is more focused on quantifiable performance metrics, particularly those related to sales and revenue. It provides a detailed breakdown of sales performance across various dimensions, which can help businesses identify areas of strength and weakness. On the other hand, #Channel_Dynamics is more focused on qualitative aspects of marketing and customer perception. It provides insights into how marketing efforts are perceived and how they influence customer behavior. Both tags are crucial for a comprehensive understanding of business performance, but they focus on different aspects of it.
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: How does the performance of our products differ by pack size?
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
# Overriding of current TracerProvider is not allowed
# # Agent: Correlation Analyst
# ## Final Answer:
# The best matching tag for the user question "How does the performance of our products differ by pack size?" is #sales. I am 90% confident in this classification. The question is focused on product performance and specifically mentions a dimension (pack size) that is covered under the #sales tag. The question does not align with the key elements of the #Channel_Dynamics tag, which are more focused on marketing efforts and customer perception.
#
#
# Question: How does the performance of our products differ by pack size?
# Intent: #sales
# ...
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# The main business goals associated with each tag are:
#
# #sales: The primary business goal is to maximize sales and understand sales performance. This includes understanding trends, comparing revenue across different regions, identifying top-performing products and segments, and understanding market share.
#
# #Channel_Dynamics: The main business goal is to understand and optimize marketing efforts. This includes understanding brand sentiment, comparing marketing spend to industry benchmarks, identifying key factors influencing customer perceptions, and tracking brand visibility and customer engagement.
#
# The key data points covered by each tag are:
#
# #sales: Sales in various currencies, trade levels (Manufacturer, Wholesaler, Public/pharmacy prices), country, corporation, anatomical therapy class, disease, product, form, strength, pack.
#
# #Channel_Dynamics: Spend, Marketing Spend, Promoter/detractors, Mentions.
#
# The dimensions that each tag encompasses are:
#
# #sales: The dimensions include geographical (country), organizational (corporation), product-related (anatomical therapy class, disease, product, form, strength, pack), and trade level.
#
# #Channel_Dynamics: The dimensions include marketing channels, customer sentiment (promoters/detractors), and brand visibility (mentions).
#
# Comparison of the two tags:
#
# #sales is primarily focused on understanding and improving the sales performance of a company. It covers a wide range of dimensions from geographical and organizational to product-related and trade levels. The data points are more quantitative, focusing on sales figures and performance metrics.
#
# #Channel_Dynamics, on the other hand, is more focused on the marketing aspect of a business. It seeks to understand how products are marketed and perceived. The dimensions are more qualitative, focusing on customer sentiment, brand visibility, and marketing channels. The data points are a mix of quantitative (spend) and qualitative (mentions, promoters/detractors) metrics.
#
# In summary, while both tags are crucial for a business, they serve different purposes. #sales is more about understanding the 'what' (sales performance) and 'where' (geographical, organizational dimensions), while #Channel_Dynamics is more about understanding the 'how' (marketing channels, spend) and 'why' (customer sentiment).
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: How many mentions is my product getting?
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
# Overriding of current TracerProvider is not allowed
# # Agent: Correlation Analyst
# ## Final Answer:
# The best matching tag for the user question "How many mentions is my product getting?" is #Channel_Dynamics. The confidence score for this classification is 90%. The reasoning behind this decision is that the user's question is focused on brand visibility and customer perception, which is covered by the #Channel_Dynamics tag. The question does not directly relate to sales performance, which is the focus of the #sales tag. Therefore, the #Channel_Dynamics tag is a better match for this question.
#
#
# Question: How many mentions is my product getting?
# Intent: #sales
# --------------------------------------------------------------------------------
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# LLM created with extracted parameters; model='gpt-4'
# # Agent: Question Analyzer
# ## Task:
#         Step 1: Read the user question carefully and extract the most relevant information.
#
#         Question to analyze: What are my competitors spending on marketing?
#
#         Focus on:
#         - What type of data the user is asking about
#         - What dimensions they're interested in
#         - What business goal they're trying to achieve
#
#         Provide a detailed analysis of the question highlighting these elements.
#
#
#
# # Agent: Question Analyzer
# ## Final Answer:
# The user's question is seeking data on the marketing expenditures of their competitors. The dimension of interest is financial, specifically within the context of marketing. The underlying business goal appears to be a desire to compare their own marketing spending to that of their competitors, potentially to evaluate their own spending levels or to gain strategic insights.
#
#
# # Agent: Tag Description Expert
# ## Task:
#         Step 2: Analyze the tag descriptions thoroughly:
#
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# Examples of #sales questions:
# 1. What is the trend of our product performance over the last quarter?
# 2. How does our revenue compare across different countries?
# 3. Which anatomical therapy class is generating the most revenue?
# 4. What are the top-performing products in the public/pharmacy price segment?
# 5. How do our sales figures vary by product form and strength?
# 6. What is the market share of our corporation in the European region?
# 7. How do sales figures differ between wholesalers and manufacturers?
# 8. What is the average price point for our products in the US market?
# 9. Which disease category is driving the highest sales for our company?
# 10. How have our sales figures changed year-over-year in the UK?
#
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
# Examples of #Channel_Dynamics questions:
# 1. What is the current sentiment around my brand in social media discussions?
# 2. How does our marketing spend compare to industry benchmarks?
# 3. What are the key factors influencing customer perceptions of our products?
# 4. How many positive reviews have we received in the last quarter?
# 5. What channels are driving the most engagement for our marketing campaigns?
# 6. How frequently are our products mentioned in online forums?
# 7. What is the average customer rating for our latest product launch?
# 8. How do our promotional efforts impact customer loyalty?
# 9. What trends are emerging in consumer feedback about our brand?
# 10. How does our brand's visibility compare to that of our main competitors?
#
#
#         Extract and list:
#         - The main business goals associated with each tag
#         - The key data points covered by each tag
#         - The dimensions that each tag encompasses
#
#         Provide a detailed comparison of the two tags based on your analysis.
#
#
#
# # Agent: Tag Description Expert
# ## Final Answer:
# The #sales tag is associated with the business goal of maximizing sales, covering data points like sales in various currencies and trade levels, and encompasses dimensions such as Country, Corporation, Anatomical Therapy Class, Disease, Product, Form, Strength, and Pack. On the other hand, the #Channel_Dynamics tag is linked to the business goal of understanding marketing effectiveness and brand perception, covering data points like marketing spend, promoter/detractor data, and brand mentions. The dimensions it encompasses are likely to include marketing channels, customer feedback platforms, and product categories. The #sales tag is focused on sales performance and revenue, while the #Channel_Dynamics tag is concerned with marketing efforts and brand perception.
#
#
# # Agent: Correlation Analyst
# ## Task:
#         Step 3: Based on the analyses from previous steps, determine which tag best matches the user question:
#
#         User Question: What are my competitors spending on marketing?
#
#         Tag Descriptions:
#
# #sales = This tag is used when a user asks questions about Sales Performance.
# Maximizing Sales is the ultimate goal of any commercial production organization so understanding Sales Performance is very important.
# The data includes information on Sales in various currencies and "Trade Levels" (eg Manufacturer, Wholesaler, Public/pharmacy prices)
# and is split by dimensions such as Country, Corporation, Anatomical Therapy Clase, Disease, Product, Form, Strength, Pack.
#
#
# #Channel_Dynamics = This tag is used when a user asks questions about any kind of Spend,
# Marketing Spend, Promoter/detractors, Mentions etc.
# The data provides information on how products are marketed and percieved.
#
#
#         Compare the elements of the question with the characteristics of each tag.
#         Look for strong correlations between:
#         - The question's focus and the tag's scope
#         - The dimensions mentioned in the question and those covered by the tag
#         - The implicit business goal of the question and the goals associated with the tag
#
#         Classify the question as either:
#         - #sales
#         - #Channel_Dynamics
#         - #somewhereelse (if it doesn't clearly match either of the first two)
#
#         Provide a confidence score (0-100%) and explain your reasoning.
#
#
#
# # Agent: Correlation Analyst
# ## Final Answer:
# The user's question "What are my competitors spending on marketing?" is best classified under the #Channel_Dynamics tag. I am 95% confident in this classification due to the strong correlation between the focus of the question (marketing spend of competitors) and the scope of the #Channel_Dynamics tag (questions about any kind of Spend, including Marketing Spend). The implicit business goal of the question also aligns with the goals associated with the #Channel_Dynamics tag.
#
#
# Question: What are my competitors spending on marketing?
# Intent: #Channel_Dynamics
# --------------------------------------------------------------------------------
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_17300\893034024.py:247: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df_results.style.set_table_styles(style_df(df_results)).applymap(highlight_intent, subset=['Intent'])
# <style type="text/css">
# #T_88f1b th {
#   background-color: #333;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_88f1b td {
#   text-align: right;
#   padding: 10px 15px;
# }
# #T_88f1b tr:nth-child(even) {
#   background-color: #2a2a2a;
# }
# #T_88f1b tr:nth-child(odd) {
#   background-color: #222;
# }
# #T_88f1b  {
#   background-color: #1a1a1a;
#   color: white;
#   border: none;
# }
# #T_88f1b_row0_col1, #T_88f1b_row3_col1, #T_88f1b_row8_col1 {
#   background-color: #e3f2fd;
#   color: #1565c0;
#   font-weight: bold;
# }
# #T_88f1b_row1_col1, #T_88f1b_row2_col1, #T_88f1b_row4_col1, #T_88f1b_row5_col1, #T_88f1b_row6_col1, #T_88f1b_row7_col1 {
#   background-color: #e8f5e9;
#   color: #2e7d32;
#   font-weight: bold;
# }
# </style>
# <table id="T_88f1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88f1b_level0_col0" class="col_heading level0 col0" >Question</th>
#       <th id="T_88f1b_level0_col1" class="col_heading level0 col1" >Intent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88f1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88f1b_row0_col0" class="data row0 col0" >What are the top three competitors in my market and their marketing strategies</td>
#       <td id="T_88f1b_row0_col1" class="data row0 col1" >#Channel_Dynamics</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88f1b_row1_col0" class="data row1 col0" >How can I improve my product's features to better meet customer needs</td>
#       <td id="T_88f1b_row1_col1" class="data row1 col1" >#sales</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_88f1b_row2_col0" class="data row2 col0" >What pricing strategy would maximize my profit margins</td>
#       <td id="T_88f1b_row2_col1" class="data row2 col1" >#sales</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_88f1b_row3_col0" class="data row3 col0" >What distribution channels should I consider for my product</td>
#       <td id="T_88f1b_row3_col1" class="data row3 col1" >#Channel_Dynamics</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_88f1b_row4_col0" class="data row4 col0" >How do our sales figures compare to those of our main competitors?</td>
#       <td id="T_88f1b_row4_col1" class="data row4 col1" >#sales</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_88f1b_row5_col0" class="data row5 col0" >How does the performance of our products differ by pack size?</td>
#       <td id="T_88f1b_row5_col1" class="data row5 col1" >#sales</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_88f1b_row6_col0" class="data row6 col0" >How does the sales performance of our new products compare to established ones?</td>
#       <td id="T_88f1b_row6_col1" class="data row6 col1" >#sales</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_88f1b_row7_col0" class="data row7 col0" >How many mentions is my product getting?</td>
#       <td id="T_88f1b_row7_col1" class="data row7 col1" >#sales</td>
#     </tr>
#     <tr>
#       <th id="T_88f1b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_88f1b_row8_col0" class="data row8 col0" >What are my competitors spending on marketing?</td>
#       <td id="T_88f1b_row8_col1" class="data row8 col1" >#Channel_Dynamics</td>
#     </tr>
#   </tbody>
# </table>

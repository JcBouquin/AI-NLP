# %%
! python3 -m venv .venv
! source .venv/bin/activate
! pip install langchain_community langchain-openai langchain-anthropic scikit-learn bs4 pandas pyarrow matplotlib lxml langgraph "mcp[cli]"

# %%
import os
from langchain_openai import ChatOpenAI
# Configuration de la clé API
os.environ['OPENAI_API_KEY'] = "sk-proj-6Gc5xEwhMZOsYA6xKN4HruNnPRcA"


# Création du modèle LLM
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
import re, os
import tiktoken

from bs4 import BeautifulSoup

from langchain_community.document_loaders import RecursiveUrlLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_anthropic import ChatAnthropic
from langchain_community.vectorstores import SKLearnVectorStore

def count_tokens(text, model="cl100k_base"):
    """
    Count the number of tokens in the text using tiktoken.

    Args:
        text (str): The text to count tokens for
        model (str): The tokenizer model to use (default: cl100k_base for GPT-4)

    Returns:
        int: Number of tokens in the text
    """
    encoder = tiktoken.get_encoding(model)
    return len(encoder.encode(text))

def bs4_extractor(html: str) -> str:
    soup = BeautifulSoup(html, "lxml")

    # Target the main article content for LangGraph documentation
    main_content = soup.find("article", class_="md-content__inner")

    # If found, use that, otherwise fall back to the whole document
    content = main_content.get_text() if main_content else soup.text

    # Clean up whitespace
    content = re.sub(r"\n\n+", "\n\n", content).strip()

    return content

def load_langgraph_docs():
    """
    Load LangGraph documentation from the official website.

    This function:
    1. Uses RecursiveUrlLoader to fetch pages from the LangGraph website
    2. Counts the total documents and tokens loaded

    Returns:
        list: A list of Document objects containing the loaded content
        list: A list of tokens per document
    """
    print("Loading LangGraph documentation...")

    # Load the documentation
    urls = ["https://langchain-ai.github.io/langgraph/concepts/",
     "https://langchain-ai.github.io/langgraph/how-tos/",
     "https://langchain-ai.github.io/langgraph/tutorials/workflows/",
     "https://langchain-ai.github.io/langgraph/tutorials/introduction/",
     "https://langchain-ai.github.io/langgraph/tutorials/langgraph-platform/local-server/",
    ]

    docs = []
    for url in urls:

        loader = RecursiveUrlLoader(
            url,
            max_depth=5,
            extractor=bs4_extractor,
        )

        # Load documents using lazy loading (memory efficient)
        docs_lazy = loader.lazy_load()

        # Load documents and track URLs
        for d in docs_lazy:
            docs.append(d)

    print(f"Loaded {len(docs)} documents from LangGraph documentation.")
    print("\nLoaded URLs:")
    for i, doc in enumerate(docs):
        print(f"{i+1}. {doc.metadata.get('source', 'Unknown URL')}")

    # Count total tokens in documents
    total_tokens = 0
    tokens_per_doc = []
    for doc in docs:
        total_tokens += count_tokens(doc.page_content)
        tokens_per_doc.append(count_tokens(doc.page_content))
    print(f"Total tokens in loaded documents: {total_tokens}")

    return docs, tokens_per_doc

def save_llms_full(documents):
    """ Save the documents to a file """

    # Open the output file with UTF-8 encoding explicitly
    output_filename = "llms_full.txt"

    with open(output_filename, "w", encoding="utf-8") as f:
        # Write each document
        for i, doc in enumerate(documents):
            # Get the source (URL) from metadata
            source = doc.metadata.get('source', 'Unknown URL')

            # Write the document with proper formatting
            f.write(f"DOCUMENT {i+1}\n")
            f.write(f"SOURCE: {source}\n")
            f.write("CONTENT:\n")
            f.write(doc.page_content)
            f.write("\n\n" + "="*80 + "\n\n")

    print(f"Documents concatenated into {output_filename}")

def split_documents(documents):
    """
    Split documents into smaller chunks for improved retrieval.

    This function:
    1. Uses RecursiveCharacterTextSplitter with tiktoken to create semantically meaningful chunks
    2. Ensures chunks are appropriately sized for embedding and retrieval
    3. Counts the resulting chunks and their total tokens

    Args:
        documents (list): List of Document objects to split

    Returns:
        list: A list of split Document objects
    """
    print("Splitting documents...")

    # Initialize text splitter using tiktoken for accurate token counting
    # chunk_size=8,000 creates relatively large chunks for comprehensive context
    # chunk_overlap=500 ensures continuity between chunks
    text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
        chunk_size=8000,
        chunk_overlap=500
    )

    # Split documents into chunks
    split_docs = text_splitter.split_documents(documents)

    print(f"Created {len(split_docs)} chunks from documents.")

    # Count total tokens in split documents
    total_tokens = 0
    for doc in split_docs:
        total_tokens += count_tokens(doc.page_content)

    print(f"Total tokens in split documents: {total_tokens}")

    return split_docs

def create_vectorstore(splits):
    """
    Create a vector store from document chunks using SKLearnVectorStore.

    This function:
    1. Initializes an embedding model to convert text into vector representations
    2. Creates a vector store from the document chunks

    Args:
        splits (list): List of split Document objects to embed

    Returns:
        SKLearnVectorStore: A vector store containing the embedded documents
    """
    print("Creating SKLearnVectorStore...")

    # Initialize OpenAI embeddings
    embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

    # Create vector store from documents using SKLearn
    persist_path = os.getcwd()+"/sklearn_vectorstore.parquet"
    vectorstore = SKLearnVectorStore.from_documents(
        documents=splits,
        embedding=embeddings,
        persist_path=persist_path   ,
        serializer="parquet",
    )
    print("SKLearnVectorStore created successfully.")

    vectorstore.persist()
    print("SKLearnVectorStore was persisted to", persist_path)

    return vectorstore

# %%
# Load the documents
documents, tokens_per_doc = load_langgraph_docs()

# Save the documents to a file
save_llms_full(documents)

# Split the documents
split_docs = split_documents(documents)
# Out:
# Loading LangGraph documentation...
# Loaded 120 documents from LangGraph documentation.
#
# Loaded URLs:
# 1. https://langchain-ai.github.io/langgraph/concepts/
# 2. https://langchain-ai.github.io/langgraph/concepts/durable_execution/
# 3. https://langchain-ai.github.io/langgraph/concepts/streaming/
# 4. https://langchain-ai.github.io/langgraph/concepts/agentic_concepts/
# 5. https://langchain-ai.github.io/langgraph/concepts/low_level/
# 6. https://langchain-ai.github.io/langgraph/concepts/memory/
# 7. https://langchain-ai.github.io/langgraph/concepts/time-travel/
# 8. https://langchain-ai.github.io/langgraph/concepts/multi_agent/
# 9. https://langchain-ai.github.io/langgraph/concepts/persistence/
# 10. https://langchain-ai.github.io/langgraph/concepts/functional_api/
# 11. https://langchain-ai.github.io/langgraph/concepts/human_in_the_loop/
# 12. https://langchain-ai.github.io/langgraph/concepts/breakpoints
# 13. https://langchain-ai.github.io/langgraph/concepts/pregel/
# 14. https://langchain-ai.github.io/langgraph/concepts/high_level/
# 15. https://langchain-ai.github.io/langgraph/concepts/faq/
# 16. https://langchain-ai.github.io/langgraph/concepts/double_texting/
# 17. https://langchain-ai.github.io/langgraph/concepts/langgraph_server/
# 18. https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/
# 19. https://langchain-ai.github.io/langgraph/concepts/sdk/
# 20. https://langchain-ai.github.io/langgraph/concepts/assistants/
# 21. https://langchain-ai.github.io/langgraph/concepts/langgraph_cli/
# 22. https://langchain-ai.github.io/langgraph/concepts/langgraph_platform/
# 23. https://langchain-ai.github.io/langgraph/concepts/application_structure/
# 24. https://langchain-ai.github.io/langgraph/concepts/auth/
# 25. https://langchain-ai.github.io/langgraph/concepts/deployment_options/
# 26. https://langchain-ai.github.io/langgraph/concepts/plans/
# 27. https://langchain-ai.github.io/langgraph/concepts/template_applications/
# 28. https://langchain-ai.github.io/langgraph/concepts/self_hosted/
# 29. https://langchain-ai.github.io/langgraph/concepts/langgraph_cloud/
# 30. https://langchain-ai.github.io/langgraph/concepts/bring_your_own_cloud/
# 31. https://langchain-ai.github.io/langgraph/concepts/breakpoints/
# 32. https://langchain-ai.github.io/langgraph/concepts/scalability_and_resilience/
# 33. https://langchain-ai.github.io/langgraph/concepts/platform_architecture/
# 34. https://langchain-ai.github.io/langgraph/how-tos/
# 35. https://langchain-ai.github.io/langgraph/how-tos/subgraph-persistence/
# 36. https://langchain-ai.github.io/langgraph/how-tos/persistence_redis/
# 37. https://langchain-ai.github.io/langgraph/how-tos/persistence_mongodb/
# 38. https://langchain-ai.github.io/langgraph/how-tos/persistence/
# 39. https://langchain-ai.github.io/langgraph/how-tos/cross-thread-persistence/
# 40. https://langchain-ai.github.io/langgraph/how-tos/persistence_postgres/
# 41. https://langchain-ai.github.io/langgraph/how-tos/cross-thread-persistence-functional/
# 42. https://langchain-ai.github.io/langgraph/how-tos/persistence-functional/
# 43. https://langchain-ai.github.io/langgraph/how-tos/create-react-agent/
# 44. https://langchain-ai.github.io/langgraph/how-tos/subgraph
# 45. https://langchain-ai.github.io/langgraph/how-tos/subgraph/
# 46. https://langchain-ai.github.io/langgraph/how-tos/subgraph-transform-state/
# 47. https://langchain-ai.github.io/langgraph/how-tos/many-tools/
# 48. https://langchain-ai.github.io/langgraph/how-tos/subgraphs-manage-state/
# 49. https://langchain-ai.github.io/langgraph/how-tos/streaming-subgraphs/
# 50. https://langchain-ai.github.io/langgraph/how-tos/command/
# 51. https://langchain-ai.github.io/langgraph/how-tos/return-when-recursion-limit-hits/
# 52. https://langchain-ai.github.io/langgraph/how-tos/configuration/
# 53. https://langchain-ai.github.io/langgraph/how-tos/map-reduce/
# 54. https://langchain-ai.github.io/langgraph/how-tos/node-retries/
# 55. https://langchain-ai.github.io/langgraph/how-tos/recursion-limit/
# 56. https://langchain-ai.github.io/langgraph/how-tos/visualization/
# 57. https://langchain-ai.github.io/langgraph/how-tos/state-reducers/
# 58. https://langchain-ai.github.io/langgraph/how-tos/branching/
# 59. https://langchain-ai.github.io/langgraph/how-tos/sequence/
# 60. https://langchain-ai.github.io/langgraph/how-tos/multi-agent-multi-turn-convo/
# 61. https://langchain-ai.github.io/langgraph/how-tos/multi-agent-network-functional/
# 62. https://langchain-ai.github.io/langgraph/how-tos/multi-agent-multi-turn-convo-functional/
# 63. https://langchain-ai.github.io/langgraph/how-tos/state-model/
# 64. https://langchain-ai.github.io/langgraph/how-tos/agent-handoffs/
# 65. https://langchain-ai.github.io/langgraph/how-tos/multi-agent-network/
# 66. https://langchain-ai.github.io/langgraph/how-tos/agent-handoffs
# 67. https://langchain-ai.github.io/langgraph/how-tos/use-remote-graph/
# 68. https://langchain-ai.github.io/langgraph/how-tos/streaming/
# 69. https://langchain-ai.github.io/langgraph/how-tos/streaming-events-from-within-tools/
# 70. https://langchain-ai.github.io/langgraph/how-tos/react-agent-from-scratch
# 71. https://langchain-ai.github.io/langgraph/how-tos/react-agent-structured-output/
# 72. https://langchain-ai.github.io/langgraph/how-tos/react-agent-from-scratch/
# 73. https://langchain-ai.github.io/langgraph/how-tos/tool-calling/
# 74. https://langchain-ai.github.io/langgraph/how-tos/streaming
# 75. https://langchain-ai.github.io/langgraph/how-tos/streaming-specific-nodes/
# 76. https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens
# 77. https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/
# 78. https://langchain-ai.github.io/langgraph/how-tos/disable-streaming/
# 79. https://langchain-ai.github.io/langgraph/how-tos/review-tool-calls-functional/
# 80. https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/edit-graph-state/
# 81. https://langchain-ai.github.io/langgraph/how-tos/wait-user-input-functional/
# 82. https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/dynamic_breakpoints/
# 83. https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/review-tool-calls/
# 84. https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/breakpoints/
# 85. https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/time-travel/
# 86. https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/wait-user-input/
# 87. https://langchain-ai.github.io/langgraph/how-tos/react-agent-from-scratch-functional
# 88. https://langchain-ai.github.io/langgraph/how-tos/react-agent-from-scratch-functional/
# 89. https://langchain-ai.github.io/langgraph/how-tos/pass_private_state/
# 90. https://langchain-ai.github.io/langgraph/how-tos/input_output_schema/
# 91. https://langchain-ai.github.io/langgraph/how-tos/async/
# 92. https://langchain-ai.github.io/langgraph/how-tos/run-id-langsmith/
# 93. https://langchain-ai.github.io/langgraph/how-tos/autogen-integration-functional/
# 94. https://langchain-ai.github.io/langgraph/how-tos/autogen-integration/
# 95. https://langchain-ai.github.io/langgraph/how-tos/create-react-agent-structured-output/
# 96. https://langchain-ai.github.io/langgraph/how-tos/react-agent-structured-output
# 97. https://langchain-ai.github.io/langgraph/how-tos/create-react-agent-memory/
# 98. https://langchain-ai.github.io/langgraph/how-tos/create-react-agent-hitl/
# 99. https://langchain-ai.github.io/langgraph/how-tos/create-react-agent-system-prompt/
# 100. https://langchain-ai.github.io/langgraph/how-tos/create-react-agent
# 101. https://langchain-ai.github.io/langgraph/how-tos/memory/manage-conversation-history/
# 102. https://langchain-ai.github.io/langgraph/how-tos/memory/delete-messages/
# 103. https://langchain-ai.github.io/langgraph/how-tos/memory/add-summary-conversation-history/
# 104. https://langchain-ai.github.io/langgraph/how-tos/memory/delete-messages
# 105. https://langchain-ai.github.io/langgraph/how-tos/memory/semantic-search/
# 106. https://langchain-ai.github.io/langgraph/how-tos/deploy-self-hosted/
# 107. https://langchain-ai.github.io/langgraph/how-tos/pass-run-time-values-to-tools/
# 108. https://langchain-ai.github.io/langgraph/how-tos/tool-calling-errors/
# 109. https://langchain-ai.github.io/langgraph/how-tos/update-state-from-tools/
# 110. https://langchain-ai.github.io/langgraph/how-tos/pass-config-to-tools/
# 111. https://langchain-ai.github.io/langgraph/how-tos/http/custom_lifespan/
# 112. https://langchain-ai.github.io/langgraph/how-tos/http/custom_middleware/
# 113. https://langchain-ai.github.io/langgraph/how-tos/http/custom_routes/
# 114. https://langchain-ai.github.io/langgraph/how-tos/local-studio/
# 115. https://langchain-ai.github.io/langgraph/how-tos/autogen-langgraph-platform/
# 116. https://langchain-ai.github.io/langgraph/how-tos/auth/openapi_security/
# 117. https://langchain-ai.github.io/langgraph/how-tos/auth/custom_auth/
# 118. https://langchain-ai.github.io/langgraph/tutorials/workflows/
# 119. https://langchain-ai.github.io/langgraph/tutorials/introduction/
# 120. https://langchain-ai.github.io/langgraph/tutorials/langgraph-platform/local-server/
# Total tokens in loaded documents: 304359
# Documents concatenated into llms_full.txt
# Splitting documents...
# Created 133 chunks from documents.
# Total tokens in split documents: 307439

# %%
# Create the vector store
vectorstore = create_vectorstore(split_docs)
# Out:
# Creating SKLearnVectorStore...
# SKLearnVectorStore created successfully.
# SKLearnVectorStore was persisted to c:\Users\kosmo\pycode\MCP/sklearn_vectorstore.parquet

# %%
# Create retriever to get relevant documents (k=3 means return top 3 matches)
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# Get relevant documents for the query
query = "What is LangGraph?"
relevant_docs = retriever.invoke(query)
print(f"Retrieved {len(relevant_docs)} relevant documents")

for d in relevant_docs:
    print(d.metadata['source'])
    print(d.page_content[0:500])
    print("\n--------------------------------\n")
# Out:
# Retrieved 3 relevant documents
# https://langchain-ai.github.io/langgraph/concepts/high_level/
# Why LangGraph?¶
# LLM applications¶
# LLMs make it possible to embed intelligence into a new class of applications. There are many patterns for building applications that use LLMs. Workflows have scaffolding of predefined code paths around LLM calls. LLMs can direct the control flow through these predefined code paths, which some consider to be an "agentic system". In other cases, it's possible to remove this scaffolding, creating autonomous agents that can plan, take actions via tool calls, and dir
#
# --------------------------------
#
# https://langchain-ai.github.io/langgraph/concepts/faq/
# FAQ¶
# Common questions and their answers!
# Do I need to use LangChain to use LangGraph? What’s the difference?¶
# No. LangGraph is an orchestration framework for complex agentic systems and is more low-level and controllable than LangChain agents. LangChain provides a standard interface to interact with models and other components, useful for straight-forward chains and retrieval flows.
# How is LangGraph different from other agent frameworks?¶
# Other agentic frameworks can work for simple, generic tas
#
# --------------------------------
#
# https://langchain-ai.github.io/langgraph/concepts/langgraph_platform/
# LangGraph Platform¶
# Overview¶
# LangGraph Platform is a commercial solution for deploying agentic applications to production, built on the open-source LangGraph framework.
# The LangGraph Platform consists of several components that work together to support the development, deployment, debugging, and monitoring of LangGraph applications:
#
# LangGraph Server: The server defines an opinionated API and architecture that incorporates best practices for deploying agentic applications, allowing you to focus
#
# --------------------------------

# %%
from langchain_core.tools import tool

@tool
def langgraph_query_tool(query: str):
    """
    Query the LangGraph documentation using a retriever.

    Args:
        query (str): The query to search the documentation with

    Returns:
        str: A str of the retrieved documents
    """
    retriever = SKLearnVectorStore(
    embedding=OpenAIEmbeddings(model="text-embedding-3-large"),
    persist_path=os.getcwd()+"/sklearn_vectorstore.parquet",
    serializer="parquet").as_retriever(search_kwargs={"k": 3})

    relevant_docs = retriever.invoke(query)
    print(f"Retrieved {len(relevant_docs)} relevant documents")
    formatted_context = "\n\n".join([f"==DOCUMENT {i+1}==\n{doc.page_content}" for i, doc in enumerate(relevant_docs)])
    return formatted_context

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
augmented_llm = llm.bind_tools([langgraph_query_tool])

instructions = """You are a helpful assistant that can answer questions about the LangGraph documentation.
Use the langgraph_query_tool for any questions about the documentation.
If you don't know the answer, say "I don't know."""

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": "What is LangGraph?"}
]

message = augmented_llm.invoke(messages)
message.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   langgraph_query_tool (call_OICAy1JTmVpRRgH5Rg2gN3LA)
#  Call ID: call_OICAy1JTmVpRRgH5Rg2gN3LA
#   Args:
#     query: What is LangGraph?

# %% [markdown]
# # Skills with Claude API

# %%
from dotenv import load_dotenv
import anthropic
from anthropic.lib import files_from_dir

_ = load_dotenv()

# %%
client = anthropic.Anthropic()

# %% [markdown]
# ## Part 1 : Content Creation

# %% [markdown]
# ### Upload the Custom Skill: Practice Question Generator

# %%
# Upload your skill directory
skill = client.beta.skills.create(
    display_title="Practice Question Generator",
    files=files_from_dir("./custom_skills/generating-practice-questions"),
    betas=["skills-2025-10-02"]
)

print(f"Skill ID: {skill.id}")
# Out:
# Skill ID: skill_013uUQDQJ9EQg6oFp9SipUyv

# %%
skills = client.beta.skills.list(source="custom")

# %%
for custom_skill in skills:
    print(f"ID: {skill.id}. Display Title: {skill.display_title}")
# Out:
# ID: skill_013uUQDQJ9EQg6oFp9SipUyv. Display Title: Practice Question Generator

# %% [markdown]
# ### Upload the Input File

# %%
file_object = client.beta.files.upload(
    file=open("./lecture_notes/notes04.tex", "rb"),
)

# %% [markdown]
# ### Send the Request

# %%
response = client.beta.messages.create(
    model="claude-sonnet-4-5-20250929",
    max_tokens=4096,
    betas=["code-execution-2025-08-25","skills-2025-10-02", "files-api-2025-04-14"],  
    container={
        "skills": [{
            "type": "custom", 
            "skill_id": skill.id, 
            "version": "latest"}]
    },
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": "Generate practice questions in Markdown format from these lecture notes"},
            {"type": "container_upload", "file_id": file_object.id}
        ]
    }],
    tools=[{
        "type": "code_execution_20250825",
        "name": "code_execution"
    }]
)

# %%
for block in response.content:
    print(block.type)
# Out:
# text
# server_tool_use
# server_tool_use
# text_editor_code_execution_tool_result
# text_editor_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# bash_code_execution_tool_result
# text

# %%
# Color codes
BOLD = "\033[1m"
RESET = "\033[0m"
BLUE = "\033[94m"
GREEN = "\033[92m"
YELLOW = "\033[93m"
CYAN = "\033[96m"

# %%
for block in response.content:
    if block.type == "text":
        print(f"{BOLD}{BLUE}[TEXT]{RESET}")
        print(block.text, "\n")
    
    if block.type == "server_tool_use":
        print(f"{BOLD}{GREEN}[SERVER_TOOL_USE]{RESET}")
        input_preview = block.input.copy()  
        if "file_text" in input_preview:
            text = input_preview["file_text"]
            if len(text) > 100:
                input_preview["file_text"] = text[:100] + " ..."
        print(input_preview, "\n")
    
    if block.type == "text_editor_code_execution_tool_result":
        print(f"{BOLD}{YELLOW}[TOOL_RESULT]{RESET}")
        content_str = str(block.content)
        preview = content_str[:100]
        if len(content_str) > 100:
            preview += " ..."
        print(preview, "\n")
    
    if block.type == "bash_code_execution_tool_result":
        print(f"{BOLD}{CYAN}[BASH_RESULT]{RESET}")
        print(block.content, "\n")
# Out:
# [TEXT]
# I'll help you generate practice questions from the lecture notes. Let me start by reading the skill file and then examining your lecture notes.
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/generating-practice-questions/SKILL.md'}
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '$INPUT_DIR/notes04.tex'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='---\nname: generating-practice-questions\ndescri ...
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content="\\documentclass[11pt,letterpaper]{article}\n\\us ...
#
# [TEXT]
# Now let me check the templates to follow the proper format:
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/generating-practice-questions/assets/markdown_template.md'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='# Markdown Template for Practice Questions\n\nUs ...
#
# [TEXT]
# Now I'll generate comprehensive practice questions based on the lecture notes about Machine Learning Models. Let me create a well-structured Markdown document:
#
# [SERVER_TOOL_USE]
# {'command': 'create', 'path': '/tmp/practice_questions_notes04.md', 'file_text': '# Practice Questions for Machine Learning Models\n\n## Instructions\n\nThese practice questions are desi ...'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionCreateResultBlock(is_file_update=False, type='text_editor_code_execution_ ...
#
# [TEXT]
# Now let me copy the file to the output directory:
#
# [SERVER_TOOL_USE]
# {'command': 'cp /tmp/practice_questions_notes04.md $OUTPUT_DIR/practice_questions_notes04.md'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[BetaBashCodeExecutionOutputBlock(file_id='file_011CbLw2d2pTjyNihedvgMSo', type='bash_code_execution_output')], return_code=0, stderr='', stdout='', type='bash_code_execution_result')
#
# [TEXT]
# Perfect! I've successfully generated comprehensive practice questions in Markdown format from your lecture notes on Machine Learning Models. Here's what I created:
#
# ## Summary of Practice Questions
#
# The practice questions cover all four learning objectives from the lecture:
#
# ### **Part 1: True/False Questions (5 questions)**
# - Tests understanding of independent/dependent variables in models
# - Covers parametric vs. non-parametric models
# - Addresses geometric interpretations of linear models
# - Includes critical thinking about model complexity
# - Tests common misconceptions
#
# ### **Part 2: Explanatory Questions (5 questions)**
# - Model components and their interactions during training vs. prediction
# - Detailed comparison of parametric vs. non-parametric models
# - Geometric interpretation of linear classification
# - Advantages and disadvantages of linear models
# - Training process for linear regression
#
# ### **Part 3: Coding Question**
# - **Topic**: Implementing simple linear regression from scratch
# - Students implement prediction, error computation, and parameter fitting functions
# - Includes function signatures, examples with expected output, and helpful hints
# - Tests practical understanding of the weighted sum concept and minimizing sum of squared errors
#
# ### **Part 4: Use Case Application**
# - **Scenario**: Predicting graduate school admission using GRE and TOEFL scores
# - Mirrors the example from the lecture notes
# - Requires data preprocessing, model training, evaluation, and visualization
# - Tests ability to interpret the decision boundary and coefficients
# - Includes data generation code and detailed requirements
#
# The questions are designed to progressively test deeper understanding, from basic concepts to practical application, aligned with the lecture's learning outcomes.

# %% [markdown]
# ### Download the File

# %%
# Extract file ID from response
file_id = None
for block in response.content:
    if block.type == 'bash_code_execution_tool_result':
        # File ID is in the tool result
        if hasattr(block, 'content') and hasattr(block.content, 'content'):
            for result_block in block.content.content:
                if hasattr(result_block, 'file_id'):
                    file_id = result_block.file_id
                    break

# %%
if file_id:
    # Download the file
    file_content = client.beta.files.download(
        file_id=file_id,
        betas=["files-api-2025-04-14"]
    )

    # Save to disk
    with open("notes04.md", "wb") as f:
        file_content.write_to_file(f.name)

# %% [markdown]
# ### Delete the Skill - Optional

# %%
# Step 1: Delete all versions
versions = client.beta.skills.versions.list(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)

for version in versions.data:
    client.beta.skills.versions.delete(
        skill_id=skill.id,
        version=version.version,
        betas=["skills-2025-10-02"]
    )

# %%
# Step 2: Delete the Skill
client.beta.skills.delete(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)
# Out:
# SkillDeleteResponse(id='skill_013uUQDQJ9EQg6oFp9SipUyv', type='skill_deleted')

# %% [markdown]
# ## Part 2 : Data Analysis

# %% [markdown]
# ### Upload the Custom Skill: Time Series Analysis

# %%
# Upload your skill directory
skill = client.beta.skills.create(
    display_title="Time Series Analysis",
    files=files_from_dir("./custom_skills/analyzing-time-series/"),
    betas=["skills-2025-10-02"]
)

print(f"Skill ID: {skill.id}")
# Out:
# Skill ID: skill_01CAgSDfR5KGmd6pkJg4pBMj

# %%
skills = client.beta.skills.list()
for sk in skills:
    print(f"ID: {sk.id}. Display Title: {sk.display_title}. Version: {sk.latest_version}")
# Out:
# ID: skill_01CAgSDfR5KGmd6pkJg4pBMj. Display Title: Time Series Analysis. Version: 1779604752533481
# ID: xlsx. Display Title: xlsx. Version: 20260203
# ID: pptx. Display Title: pptx. Version: 20260304
# ID: pdf. Display Title: pdf. Version: 20260203
# ID: docx. Display Title: docx. Version: 20260212

# %% [markdown]
# ### Upload the Input File

# %%
file_object = client.beta.files.upload(
    file=open("./data/retail_sales.csv", "rb"),
)

# %% [markdown]
# ### Send the Request

# %%
query= """
Analyze and visualize this time series data. 
Create a word doc report summarizing the diagnostic results and plots.
"""

# %%
response = client.beta.messages.create(
    model="claude-sonnet-4-5-20250929",
    max_tokens=16384,
    betas=["code-execution-2025-08-25","skills-2025-10-02", "files-api-2025-04-14"],  
    container={
        "skills": [
            {"type": "custom", "skill_id": skill.id, "version": "latest"},
            {"type": "anthropic", "skill_id":"docx", "version": "20251013"}
        ]
    },
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": query},
            {"type": "container_upload", "file_id": file_object.id}
        ]
    }],
    tools=[{
        "type": "code_execution_20250825",
        "name": "code_execution"
    }]
)

# %%
for block in response.content:
    print(block.type)
# Out:
# text
# server_tool_use
# server_tool_use
# text_editor_code_execution_tool_result
# text_editor_code_execution_tool_result
# text
# server_tool_use
# bash_code_execution_tool_result
# server_tool_use
# bash_code_execution_tool_result
# text
# server_tool_use
# server_tool_use
# text_editor_code_execution_tool_result
# bash_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# server_tool_use
# bash_code_execution_tool_result
# server_tool_use
# bash_code_execution_tool_result
# text

# %%
for block in response.content:
    if block.type == "text":
        print(f"{BOLD}{BLUE}[TEXT]{RESET}")
        print(block.text, "\n")
    
    if block.type == "server_tool_use":
        print(f"{BOLD}{GREEN}[SERVER_TOOL_USE]{RESET}")
        input_preview = block.input.copy()  
        if "file_text" in input_preview:
            text = input_preview["file_text"]
            if len(text) > 100:
                input_preview["file_text"] = text[:100] + " ..."
        print(input_preview, "\n")
    
    if block.type == "text_editor_code_execution_tool_result":
        print(f"{BOLD}{YELLOW}[TOOL_RESULT]{RESET}")
        content_str = str(block.content)
        preview = content_str[:100]
        if len(content_str) > 100:
            preview += " ..."
        print(preview, "\n")
    
    if block.type == "bash_code_execution_tool_result":
        print(f"{BOLD}{CYAN}[BASH_RESULT]{RESET}")
        print(block.content, "\n")
# Out:
# [TEXT]
# I'll analyze the time series data and create a Word document report with diagnostic results and plots. Let me start by reading the relevant skill files.
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/analyzing-time-series/SKILL.md'}
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/docx/SKILL.md'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='---\nname: analyzing-time-series\ndescription: C ...
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='---\nname: docx\ndescription: "Comprehensive doc ...
#
# [TEXT]
# Now let me execute the time series analysis workflow and then create the Word document report.
#
# [SERVER_TOOL_USE]
# {'command': 'cd /skills/analyzing-time-series && python scripts/diagnose.py $INPUT_DIR/retail_sales.csv --output-dir /tmp/results/'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr="/skills/analyzing-time-series/scripts/ts_utils.py:131: InterpolationWarning: The test statistic is outside of the range of p-values available in the\nlook-up table. The actual p-value is smaller than the p-value returned.\n\n  kpss_result = kpss(clean_series, regression='c', nlags='auto')\n", stdout='\n============================================================\nTIME SERIES DIAGNOSTICS\n============================================================\n\nLoaded 120 observations (2015-01-01 to 2024-12-01)\n\nRunning analyses...\n  [1/8] Data quality\n  [2/8] Distribution\n  [3/8] Stationarity tests (ADF, KPSS)\n  [4/8] Seasonality (STL decomposition)\n  [5/8] Trend analysis\n  [6/8] Autocorrelation (ACF, PACF)\n  [7/8] Forecastability (Ljung-Box)\n  [8/8] Transform recommendation (Box-Cox)\n\nOutput saved to /tmp/results/\n  - diagnostics.json\n  - summary.txt\n  - diagnostics_state.json\n\n============================================================\nQUICK SUMMARY\n============================================================\nForecastable: Yes\nStationary: No (d=1)\nSeasonal: Yes (period=12)\nTrend: increasing\n', type='bash_code_execution_result')
#
# [SERVER_TOOL_USE]
# {'command': 'cd /skills/analyzing-time-series && python scripts/visualize.py $INPUT_DIR/retail_sales.csv --output-dir /tmp/results/'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr='', stdout='Found diagnostics_state.json - synchronizing with diagnose.py results\n\nGenerating plots for 120 observations...\n\nPlots:\n  Created: timeseries.png\n  Created: histogram.png\n  Created: rolling_stats.png\n  Created: box_by_month.png\n  Created: box_by_quarter.png\n  Created: acf_pacf.png (first difference (d=1))\n  Created: decomposition.png (period=12)\n  Created: lag_scatter.png\n\nAll plots saved to: /tmp/results/plots/\n[OK] Plots synchronized with diagnose.py results\n', type='bash_code_execution_result')
#
# [TEXT]
# Now let me read the summary and diagnostic results:
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/tmp/results/summary.txt'}
#
# [SERVER_TOOL_USE]
# {'command': 'cat /tmp/results/diagnostics.json | jq .'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='TIME SERIES DIAGNOSTICS SUMMARY\n=============== ...
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr='', stdout='{\n  "data_quality": {\n    "n_observations": 120,\n    "date_start": "2015-01-01",\n    "date_end": "2024-12-01",\n    "frequency": "monthly",\n    "missing_values": 0,\n    "missing_pct": 0\n  },\n  "distribution": {\n    "mean": 87131.2667,\n    "median": 88524.5,\n    "std": 22759.0687,\n    "min": 33927,\n    "max": 134022,\n    "skewness": -0.0878,\n    "kurtosis": -0.722\n  },\n  "stationarity": {\n    "adf_statistic": -0.6415,\n    "adf_p_value": 0.8613,\n    "adf_stationary": false,\n    "kpss_statistic": 1.681,\n    "kpss_p_value": 0.01,\n    "kpss_stationary": false,\n    "differencing_needed": 1,\n    "differencing_verified": true,\n    "series_used_for_acf": "differenced_d1"\n  },\n  "seasonality": {\n    "is_seasonal": true,\n    "period": 12,\n    "strength": 0.9459\n  },\n  "trend": {\n    "has_trend": true,\n    "direction": "increasing",\n    "strength": 0.9837,\n    "slope_normalized": 0.025717\n  },\n  "autocorrelation": {\n    "significant_acf_lags": [\n      1,\n      6,\n      11,\n      12,\n      24,\n      30,\n      36\n    ],\n    "significant_pacf_lags": [\n      1,\n      6,\n      7,\n      8,\n      9,\n      10,\n      11,\n      12,\n      13,\n      14\n    ],\n    "confidence_threshold": 0.1797\n  },\n  "forecastability": {\n    "ljung_box_results": {\n      "lag_10": {\n        "statistic": 25.1154,\n        "p_value": 0.0051\n      },\n      "lag_20": {\n        "statistic": 118.8107,\n        "p_value": 0\n      },\n      "lag_23": {\n        "statistic": 122.5957,\n        "p_value": 0\n      }\n    },\n    "min_p_value": 0,\n    "is_white_noise": false,\n    "forecastable": true\n  },\n  "transform": {\n    "variance_stable": true,\n    "recommendation": "none",\n    "boxcox_lambda": 1.0256,\n    "note": "Box-Cox λ ≈ 1, no transform needed"\n  }\n}\n', type='bash_code_execution_result')
#
# [TEXT]
# Now let me read the docx-js.md file to create the Word document report:
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/docx/docx-js.md'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='# DOCX Library Tutorial\n\nGenerate .docx files  ...
#
# [TEXT]
# Now I'll create a JavaScript file to generate the Word document report with the diagnostic results and plots:
#
# [SERVER_TOOL_USE]
# {'command': 'create', 'path': '/tmp/create_report.js', 'file_text': "const fs = require('fs');\nconst { Document, Packer, Paragraph, TextRun, Table, TableRow, TableCell,  ..."}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionCreateResultBlock(is_file_update=False, type='text_editor_code_execution_ ...
#
# [SERVER_TOOL_USE]
# {'command': 'cd /tmp && node create_report.js'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr='', stdout='Report created: time_series_report.docx\n', type='bash_code_execution_result')
#
# [SERVER_TOOL_USE]
# {'command': 'cp /tmp/time_series_report.docx $OUTPUT_DIR/ && ls -lh /tmp/time_series_report.docx'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[BetaBashCodeExecutionOutputBlock(file_id='file_011CbLwLsNHJW9BhhaQvk8kd', type='bash_code_execution_output')], return_code=0, stderr='', stdout='-rw-r--r-- 1 root root 680K May 24 06:41 /tmp/time_series_report.docx\n', type='bash_code_execution_result')
#
# [TEXT]
# Perfect! I've successfully analyzed the time series data and created a comprehensive Word document report. Here's what was accomplished:
#
# ## Analysis Completed:
#
# **Time Series Diagnostics:**
# - **120 monthly observations** from January 2015 to December 2024
# - **No missing values** - complete dataset
# - **Forecastable**: Yes - contains predictable patterns
# - **Non-stationary** - requires first-order differencing (d=1)
# - **Strong monthly seasonality** (period=12, strength=0.95)
# - **Strong increasing trend** (strength=0.98)
#
# ## Report Contents:
#
# The Word document includes 9 comprehensive sections:
#
# 1. **Executive Summary** - Key findings at a glance
# 2. **Data Quality** - Complete dataset information and time series plot
# 3. **Distribution Analysis** - Statistical properties with histogram
# 4. **Stationarity Analysis** - ADF and KPSS test results with rolling statistics plot
# 5. **Seasonality Analysis** - Decomposition plots and monthly/quarterly patterns
# 6. **Trend Analysis** - Trend characteristics and quarterly boxplots
# 7. **Autocorrelation Analysis** - ACF/PACF plots and lag scatter analysis
# 8. **Forecastability Assessment** - Ljung-Box test results confirming forecastability
# 9. **Conclusions and Recommendations** - Modeling guidance (SARIMA suggested)
#
# The report includes **8 diagnostic plots** embedded throughout and is professionally formatted with tables, bullet points, and a clear visual hierarchy.
#
# The file **time_series_report.docx** (680KB) has been exported and is ready for download!

# %% [markdown]
# ### Download the File

# %%
# Extract file ID from response
file_id = None
for block in response.content:
    if (block.type == 'bash_code_execution_tool_result'):
        if hasattr(block, 'content') and hasattr(block.content, 'content'):
            for result_block in block.content.content:
                if hasattr(result_block, 'file_id'):
                    file_id = result_block.file_id
                    break

# %%
if file_id:
    # Download the file
    file_content = client.beta.files.download(
        file_id=file_id,
        betas=["files-api-2025-04-14"]
    )

    # Save to disk
    with open("report.docx", "wb") as f:
        file_content.write_to_file(f.name)

# %% [markdown]
# ### Delete the Skill - Optional

# %%
# Step 1: Delete all versions
versions = client.beta.skills.versions.list(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)

for version in versions.data:
    client.beta.skills.versions.delete(
        skill_id=skill.id,
        version=version.version,
        betas=["skills-2025-10-02"]
    )

# %%
# Step 2: Delete the Skill
client.beta.skills.delete(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)
# Out:
# SkillDeleteResponse(id='skill_01CAgSDfR5KGmd6pkJg4pBMj', type='skill_deleted')
